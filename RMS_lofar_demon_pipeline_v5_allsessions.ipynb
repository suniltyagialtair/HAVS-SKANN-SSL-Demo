# %% [markdown]
# # LOFAR + DEMON Hydrophone Analysis Pipeline (v5)
# ## Two-Stage Vessel Detection with Conditional DEMON Blade-Rate Extraction
# ### NUWR Goa — 512 Hz Hydrophone Recordings
#
# **Input:** 1-hour WAV files from seabed hydrophone (512 Hz sample rate)
# **Output:** Per-window CSV with LOFAR features + conditional DEMON blade-rate/shaft-rate, event list, spectrograms, customer-format CSV
#
# ---
#
# ### Pipeline Architecture
#
# | Stage | Purpose | Method | Output |
# |-------|---------|--------|--------|
# | **Stage 1 — Detection** | Is something there? | RMS energy per 30s window, σ-threshold | Detection flag, energy level |
# | **Stage 2 — Classification** | What does it look like? | STFT → background normalisation → tonal detection | Tonal frequencies, spectral fingerprint |
# | **Stage 3 — Characterisation** | Propeller parameters (conditional) | Hilbert envelope → DEMON spectrum, LOFAR-informed bandpass | Blade rate, shaft rate, RPM, confidence flag |
#
# **Stage 3 runs ONLY on windows where Stage 1 confirms elevated energy AND Stage 2 confirms tonal signatures.**
# At 512 Hz, DEMON operates on low-frequency machinery noise (not cavitation — that requires 20–50 kHz).
# Results are flagged as HIGH (harmonics confirmed, strong RMS, multiple tonals) / LOW / NONE confidence.
#
# **Processing time:** ~30 min for 48 hours (Stages 1+2: ~25 min, Stage 3 conditional: ~5 min)
#
# **Note:** Ocean swell frequencies (0.05–0.1 Hz) and microseisms (0.1–1.0 Hz) are well below
# the DEMON blade-rate search range (2–50 Hz), so no swell-band exclusion is needed.

# %% [markdown]
# ## 1. Setup & Imports

# %%
# !pip install soundfile -q

import numpy as np
import soundfile as sf
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from scipy.signal import spectrogram as scipy_spectrogram
from scipy.signal import welch, find_peaks, hilbert, butter, sosfilt
from datetime import datetime, timedelta
from pathlib import Path
import os, re, json, warnings, time as _time, gc
warnings.filterwarnings('ignore')

print('All imports OK (including scipy.signal.hilbert, butter, sosfilt for DEMON)')
# Out:
# All imports OK (including scipy.signal.hilbert, butter, sosfilt for DEMON)

# %% [markdown]
# ## 2. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
print('Drive mounted')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted

# %% [markdown]
# ## 3. Configuration
#
# Edit this cell to match your deployment.

# %%
# =====================================================================
# DATA PATHS — Recording 3: 07–09 Feb 2026 (days 11–13 of trial)
# =====================================================================
WAV_DIRS = [
    '/content/drive/MyDrive/SKANN_SSL/authorised_sessions/',
]

# Sessions to process (set to None for all files in WAV_DIRS)
KEEP_SESSIONS = None  # all sessions

# Output directory
OUTPUT_DIR = '/content/drive/MyDrive/SKANN_SSL/lofar_results_all_sessions/'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# =====================================================================
# SPECTROGRAM PARAMETERS (Stage 2)
# =====================================================================
STFT_WINDOW_SEC = 4.0       # seconds → 0.25 Hz native resolution
STFT_OVERLAP_FRAC = 0.75    # 75% overlap → ~1 spectrum/second
STFT_NFFT_MULT = 2          # zero-pad factor → 0.125 Hz bins
FREQ_MAX_HZ = 256           # display/analysis up to Nyquist

# =====================================================================
# ANALYSIS WINDOWS (for CSV output)
# =====================================================================
ANALYSIS_WINDOW_SEC = 30     # seconds per output row
ANALYSIS_HOP_SEC = 15        # hop → 50% overlap

# =====================================================================
# BACKGROUND NORMALISATION (Stage 2)
# =====================================================================
BACKGROUND_PERCENTILE = 50   # median

# =====================================================================
# TONAL DETECTION (Stage 2)
# =====================================================================
TONAL_THRESHOLD_DB = 8.0     # dB above normalised background to count as tonal
TONAL_MIN_PERSIST_SEC = 30   # must persist this long to be "real"
TONAL_FREQ_MIN_HZ = 3.5     # ignore below this (low-frequency noise)
TONAL_FREQ_MAX_HZ = 256     # upper limit
TONAL_PEAK_PROMINENCE_DB = 3.0
TONAL_PEAK_MIN_DISTANCE_HZ = 1.0

# =====================================================================
# EVENT DETECTION (Stage 1)
# =====================================================================
RMS_SIGMA_THRESHOLD = 1.0    # σ above mean for elevated energy
EVENT_MERGE_RADIUS = 8       # ±8 windows for temporal merging (120s)
EVENT_MIN_WINDOWS = 5        # minimum windows per event
SIGNIFICANT_DURATION_MIN = 5 # minutes for "significant" transit
SIGNIFICANT_RMS_FACTOR = 5.0 # ×background for "significant" transit

# =====================================================================
# DEMON PARAMETERS (Stage 3 — conditional)
# =====================================================================
# Stage 3 only runs on windows where:
#   - RMS energy > DEMON_RMS_GATE × global mean (Stage 1 confirms vessel)
#   - n_tonals >= DEMON_MIN_TONALS (Stage 2 confirms tonal structure)
# Otherwise blade_rate and shaft_rate are left blank.
DEMON_RMS_GATE = 3.0         # ×mean RMS to trigger DEMON
DEMON_MIN_TONALS = 2         # minimum tonals from Stage 2
DEMON_BLADE_RATE_MIN = 2.0   # Hz — lower bound of blade-rate search
DEMON_BLADE_RATE_MAX = 50.0  # Hz — upper search limit
DEMON_FFT_PAD = 4            # zero-pad factor for envelope FFT
DEMON_FILTER_ORDER = 4       # Butterworth bandpass order
DEMON_FALLBACK_BP = (20, 200)  # Hz — fallback bandpass if no LOFAR guidance

# =====================================================================
# SPECTROGRAM IMAGE GENERATION
# =====================================================================
GENERATE_FILE_SPECTROGRAMS = True
GENERATE_EVENT_SPECTROGRAMS = True
EVENT_PADDING_MIN = 5
EVENT_SPEC_MIN_RMS_FACTOR = 10.0

# =====================================================================
# CHECKPOINT
# =====================================================================
CHECKPOINT_FILE = os.path.join(OUTPUT_DIR, '_checkpoint.json')

# =====================================================================
# PLOT STYLE
# =====================================================================
STYLE = {
    'bg': '#0a1628', 'text': '#caf0f8', 'accent': '#00b4d8',
    'highlight': '#ff6b35', 'green': '#2ecc71', 'red': '#e74c3c',
    'box_fill': '#0d2137', 'box_edge': '#234567',
    'cmap': 'inferno',
}

print('Configuration loaded')
print(f'  STFT: {STFT_WINDOW_SEC}s window, {STFT_OVERLAP_FRAC*100:.0f}% overlap, {STFT_NFFT_MULT}x zero-pad')
print(f'  Analysis windows: {ANALYSIS_WINDOW_SEC}s / {ANALYSIS_HOP_SEC}s hop')
print(f'  Tonal detection: >{TONAL_THRESHOLD_DB} dB, >{TONAL_MIN_PERSIST_SEC}s, {TONAL_FREQ_MIN_HZ}–{TONAL_FREQ_MAX_HZ} Hz')
print(f'  Event detection: {RMS_SIGMA_THRESHOLD}σ RMS, ±{EVENT_MERGE_RADIUS} merge')
print(f'  DEMON gating: RMS >{DEMON_RMS_GATE}× mean AND ≥{DEMON_MIN_TONALS} tonals')
print(f'  DEMON blade-rate range: {DEMON_BLADE_RATE_MIN}–{DEMON_BLADE_RATE_MAX} Hz')
print(f'  Sessions: {min(KEEP_SESSIONS)}–{max(KEEP_SESSIONS)}' if KEEP_SESSIONS else '  Sessions: ALL')
print(f'  Output: {OUTPUT_DIR}')
# Out:
# Configuration loaded
#   STFT: 4.0s window, 75% overlap, 2x zero-pad
#   Analysis windows: 30s / 15s hop
#   Tonal detection: >8.0 dB, >30s, 3.5–256 Hz
#   Event detection: 1.0σ RMS, ±8 merge
#   DEMON gating: RMS >3.0× mean AND ≥2 tonals
#   DEMON blade-rate range: 2.0–50.0 Hz
#   Sessions: ALL
#   Output: /content/drive/MyDrive/SKANN_SSL/lofar_results_all_sessions/

# %% [markdown]
# ## 4. Discover & Sort WAV Files

# %%
def parse_filename(fname):
    """Extract session number and start timestamp from filename."""
    m = re.match(r'session_(\d+)_(\d{4}-\d{2}-\d{2})_(\d{2}-\d{2}-\d{2})_to_', fname)
    if not m:
        return None, None
    session = int(m.group(1))
    ts = datetime.strptime(f'{m.group(2)}_{m.group(3)}', '%Y-%m-%d_%H-%M-%S')
    return session, ts

# Gather all WAV files
all_files = []
for d in WAV_DIRS:
    if not os.path.exists(d):
        print(f'WARNING: {d} not found')
        continue
    for f in sorted(os.listdir(d)):
        if not f.endswith('.wav'):
            continue
        session, ts = parse_filename(f)
        if session is None:
            continue
        if KEEP_SESSIONS and session not in KEEP_SESSIONS:
            continue
        all_files.append({
            'filename': f,
            'path': os.path.join(d, f),
            'session': session,
            'start_ts': ts,
        })

all_files = sorted(all_files, key=lambda x: x['start_ts'])

print(f'Found {len(all_files)} WAV files to process')
if all_files:
    print(f'  First: session {all_files[0]["session"]} — {all_files[0]["start_ts"]}')
    print(f'  Last:  session {all_files[-1]["session"]} — {all_files[-1]["start_ts"]}')
    total_hours = (all_files[-1]['start_ts'] - all_files[0]['start_ts']).total_seconds() / 3600 + 1
    print(f'  Coverage: ~{total_hours:.0f} hours')
# Out:
# Found 288 WAV files to process
#   First: session 1 — 2026-01-30 09:04:07
#   Last:  session 288 — 2026-02-11 06:50:36
#   Coverage: ~287 hours

# %% [markdown]
# ## 5. Processing Functions
#
# ### Stages 1 & 2: RMS Energy + LOFAR Tonal Detection (unchanged from v3)
# ### Stage 3: DEMON Blade-Rate Extraction (NEW — conditional on Stages 1+2)

# %%
# =====================================================================
# STAGE 2: LOFAR FUNCTIONS (unchanged from v3)
# =====================================================================

def compute_stft(audio, sr):
    """Compute STFT spectrogram.
    Returns freqs (Hz), times (seconds), Sxx (power spectral density)."""
    nperseg = int(STFT_WINDOW_SEC * sr)
    noverlap = int(nperseg * STFT_OVERLAP_FRAC)
    nfft = nperseg * STFT_NFFT_MULT

    freqs, times, Sxx = scipy_spectrogram(
        audio, fs=sr, nperseg=nperseg, noverlap=noverlap,
        nfft=nfft, mode='psd', scaling='density'
    )
    return freqs, times, Sxx


def normalise_spectrogram(freqs, times, Sxx):
    """Normalise spectrogram against background (median spectrum).
    Returns normalised spectrogram in dB above background."""
    background = np.percentile(Sxx, BACKGROUND_PERCENTILE, axis=1, keepdims=True)
    background = np.maximum(background, 1e-20)
    spec_norm = Sxx / background
    spec_db = 10 * np.log10(np.maximum(spec_norm, 1e-10))
    return spec_db, background.squeeze()


def detect_tonals_in_window(spec_db_window, freqs):
    """Detect tonal peaks in a single normalised spectrum.
    Returns list of {freq_hz, strength_db, prominence_db}."""
    mask = (freqs >= TONAL_FREQ_MIN_HZ) & (freqs <= TONAL_FREQ_MAX_HZ)
    f_sub = freqs[mask]
    s_sub = spec_db_window[mask]

    if len(s_sub) < 10:
        return []

    freq_res = freqs[1] - freqs[0] if len(freqs) > 1 else 0.125
    min_distance = max(1, int(TONAL_PEAK_MIN_DISTANCE_HZ / freq_res))

    peaks, properties = find_peaks(
        s_sub,
        height=TONAL_THRESHOLD_DB,
        prominence=TONAL_PEAK_PROMINENCE_DB,
        distance=min_distance,
    )

    tonals = []
    for i, pk in enumerate(peaks):
        tonals.append({
            'freq_hz': float(f_sub[pk]),
            'strength_db': float(s_sub[pk]),
            'prominence_db': float(properties['prominences'][i]),
        })

    return sorted(tonals, key=lambda t: t['strength_db'], reverse=True)


def detect_persistent_tonals(spec_db, freqs, times):
    """Track tonals across time to find persistent narrowband lines.
    Groups into 2 Hz bands, requires sustained presence."""
    freq_mask = (freqs >= TONAL_FREQ_MIN_HZ) & (freqs <= TONAL_FREQ_MAX_HZ)
    f_sub = freqs[freq_mask]
    s_sub = spec_db[freq_mask, :]

    if len(times) < 2 or len(f_sub) < 2:
        return []

    dt = times[1] - times[0]
    min_frames = max(1, int(TONAL_MIN_PERSIST_SEC / dt))
    freq_res = freqs[1] - freqs[0]

    band_width_hz = 2.0
    band_width_bins = max(1, int(band_width_hz / freq_res))
    n_bands = len(f_sub) // band_width_bins
    band_freqs = []
    band_spec = np.zeros((n_bands, s_sub.shape[1]))
    for bi in range(n_bands):
        start_bin = bi * band_width_bins
        end_bin = min(start_bin + band_width_bins, len(f_sub))
        band_spec[bi, :] = np.max(s_sub[start_bin:end_bin, :], axis=0)
        peak_bin = start_bin + np.argmax(np.mean(s_sub[start_bin:end_bin, :], axis=1))
        band_freqs.append(float(f_sub[peak_bin]))

    above = band_spec > TONAL_THRESHOLD_DB
    persistent = []

    for bi in range(n_bands):
        row = above[bi, :]
        start_idx = None
        for ti in range(len(row)):
            if row[ti] and start_idx is None:
                start_idx = ti
            elif not row[ti] and start_idx is not None:
                if ti - start_idx >= min_frames:
                    persistent.append({
                        'freq_hz': band_freqs[bi],
                        'start_sec': float(times[start_idx]),
                        'end_sec': float(times[ti - 1]),
                        'duration_sec': float(times[ti - 1] - times[start_idx]),
                        'mean_db': float(np.mean(band_spec[bi, start_idx:ti])),
                        'max_db': float(np.max(band_spec[bi, start_idx:ti])),
                    })
                start_idx = None
        if start_idx is not None and len(row) - start_idx >= min_frames:
            persistent.append({
                'freq_hz': band_freqs[bi],
                'start_sec': float(times[start_idx]),
                'end_sec': float(times[-1]),
                'duration_sec': float(times[-1] - times[start_idx]),
                'mean_db': float(np.mean(band_spec[bi, start_idx:])),
                'max_db': float(np.max(band_spec[bi, start_idx:])),
            })

    return sorted(persistent, key=lambda t: t['mean_db'], reverse=True)


# =====================================================================
# STAGE 3: DEMON BLADE-RATE EXTRACTION (NEW)
# =====================================================================
# Runs ONLY when Stage 1 (RMS) and Stage 2 (tonals) confirm a vessel.
# Bandpass selection is informed by LOFAR tonal detections — no PSO needed.
#
# At 512 Hz, this operates on low-frequency machinery noise, NOT cavitation
# (which requires 20–50 kHz). Results are flagged with confidence accordingly.
# =====================================================================

def _design_demon_bandpass(tonal_freqs_hz, sr):
    """Design a bandpass filter informed by LOFAR tonal detections.

    Strategy:
    - If LOFAR found tonals: centre the bandpass on the strongest tonal cluster,
      wide enough to capture nearby lines.
    - If no usable tonals: fall back to a wide bandpass (20–200 Hz).

    Returns (sos, low_hz, high_hz) — the filter and its bounds.
    """
    nyquist = sr / 2.0

    if tonal_freqs_hz and len(tonal_freqs_hz) > 0:
        # Use the strongest tonal cluster
        # Find the median frequency of detected tonals as the centre
        freqs = sorted(tonal_freqs_hz)
        centre = np.median(freqs)

        # Bandwidth: span from lowest to highest tonal, plus ±20 Hz padding
        # but at least 40 Hz wide
        span = max(freqs) - min(freqs) if len(freqs) > 1 else 0
        half_bw = max(20, (span / 2) + 20)

        low_hz = max(5.0, centre - half_bw)   # stay above 5 Hz
        high_hz = min(nyquist * 0.9, centre + half_bw)  # stay below Nyquist
    else:
        # Fallback: wide bandpass
        low_hz, high_hz = DEMON_FALLBACK_BP
        high_hz = min(high_hz, nyquist * 0.9)

    # Ensure valid filter range
    if high_hz <= low_hz + 5:
        low_hz, high_hz = DEMON_FALLBACK_BP
        high_hz = min(high_hz, nyquist * 0.9)

    sos = butter(DEMON_FILTER_ORDER, [low_hz, high_hz], btype='band',
                 fs=sr, output='sos')
    return sos, low_hz, high_hz


def compute_demon_features(audio_chunk, sr, tonal_freqs_hz):
    """Run DEMON envelope analysis on a single 30-second audio chunk.

    1. Bandpass filter (informed by LOFAR tonals or fallback wideband)
    2. Hilbert transform → envelope extraction
    3. AC-couple (remove mean)
    4. Zero-padded FFT → modulation spectrum
    5. Peak detection in blade-rate range (2–50 Hz)
    6. Harmonic consistency check (2×, 3× fundamental)

    Returns dict with blade_rate_hz, shaft_rate_hz, est_n_blades,
    demon_score, bandpass used, or None values if no clear peak found.
    """
    # Design bandpass from LOFAR information
    try:
        sos, bp_low, bp_high = _design_demon_bandpass(tonal_freqs_hz, sr)
        filtered = sosfilt(sos, audio_chunk)
    except Exception:
        # Filter design can fail near Nyquist — use fallback
        try:
            low, high = DEMON_FALLBACK_BP
            high = min(high, sr / 2 * 0.9)
            sos = butter(DEMON_FILTER_ORDER, [low, high], btype='band',
                         fs=sr, output='sos')
            filtered = sosfilt(sos, audio_chunk)
            bp_low, bp_high = low, high
        except Exception:
            return _empty_demon_result()

    # Hilbert envelope
    analytic = hilbert(filtered)
    envelope = np.abs(analytic)

    # AC-couple (remove DC)
    envelope_ac = envelope - np.mean(envelope)

    # Zero-padded FFT of envelope → modulation spectrum
    n_fft = len(envelope_ac) * DEMON_FFT_PAD
    fft_result = np.fft.rfft(envelope_ac, n=n_fft)
    mod_freqs = np.fft.rfftfreq(n_fft, d=1.0 / sr)
    mod_spectrum = np.abs(fft_result) / len(envelope_ac)

    # Search for blade-rate peaks in the valid range
    br_mask = (mod_freqs >= DEMON_BLADE_RATE_MIN) & (mod_freqs <= DEMON_BLADE_RATE_MAX)
    if not br_mask.any():
        return _empty_demon_result()

    br_freqs = mod_freqs[br_mask]
    br_spec = mod_spectrum[br_mask]

    # Find peaks with minimum prominence
    freq_res = mod_freqs[1] - mod_freqs[0] if len(mod_freqs) > 1 else 0.01
    min_dist = max(1, int(1.0 / freq_res))  # at least 1 Hz apart

    peaks, props = find_peaks(br_spec, prominence=np.median(br_spec) * 0.5,
                              distance=min_dist)

    if len(peaks) == 0:
        return _empty_demon_result()

    # Take the strongest peak as candidate blade rate
    best_idx = peaks[np.argmax(props['prominences'])]
    blade_rate = float(br_freqs[best_idx])
    blade_prominence = float(props['prominences'][np.argmax(props['prominences'])])

    # Check for harmonics at 2× and 3× blade rate
    harmonic_score = 0
    for mult in [2, 3]:
        target = blade_rate * mult
        if target > DEMON_BLADE_RATE_MAX or target > sr / 2:
            continue
        h_idx = np.argmin(np.abs(mod_freqs - target))
        # Is there a peak near the expected harmonic?
        local_region = mod_spectrum[max(0, h_idx-3):h_idx+4]
        if len(local_region) > 0 and np.max(local_region) > np.median(br_spec) * 1.5:
            harmonic_score += 1

    # Estimate shaft rate and blade count
    # Try common blade counts (3, 4, 5) and see which gives a shaft-rate
    # sub-harmonic that matches a peak in the spectrum
    best_n_blades = 4  # default assumption
    best_shaft_match = 0
    for n_blades in [3, 4, 5]:
        shaft_rate = blade_rate / n_blades
        if shaft_rate < 0.5:
            continue
        s_idx = np.argmin(np.abs(mod_freqs - shaft_rate))
        local_region = mod_spectrum[max(0, s_idx-2):s_idx+3]
        if len(local_region) > 0:
            match_strength = np.max(local_region) / np.median(br_spec)
            if match_strength > best_shaft_match:
                best_shaft_match = match_strength
                best_n_blades = n_blades

    shaft_rate = blade_rate / best_n_blades
    rpm = shaft_rate * 60

    # Compute a simple DEMON quality score
    # (prominence of blade-rate peak + harmonic bonus, no fixed saturation)
    noise_floor = np.median(br_spec)
    snr = blade_prominence / noise_floor if noise_floor > 0 else 0
    demon_score = snr + harmonic_score * 2.0

    return {
        'blade_rate_hz': round(blade_rate, 2),
        'shaft_rate_hz': round(shaft_rate, 3),
        'est_n_blades': best_n_blades,
        'est_rpm': round(rpm, 1),
        'demon_score': round(demon_score, 2),
        'demon_harmonics': harmonic_score,
        'demon_bp_low': round(bp_low, 1),
        'demon_bp_high': round(bp_high, 1),
    }


def _empty_demon_result():
    """Return empty DEMON result dict (no detection)."""
    return {
        'blade_rate_hz': None,
        'shaft_rate_hz': None,
        'est_n_blades': None,
        'est_rpm': None,
        'demon_score': 0.0,
        'demon_harmonics': 0,
        'demon_bp_low': None,
        'demon_bp_high': None,
    }


# =====================================================================
# COMBINED: Process one analysis window (Stages 1 + 2 + conditional 3)
# =====================================================================

def process_analysis_window(audio_chunk, sr, spec_db_chunk, freqs, times_chunk,
                            rms_mean_global=None):
    """Process a single 30-second analysis window through all stages.

    Stage 1: RMS energy (always runs)
    Stage 2: LOFAR tonal detection (always runs)
    Stage 3: DEMON blade-rate (only if Stage 1 + Stage 2 thresholds met)

    rms_mean_global: if provided, used for DEMON gating. If None, Stage 3 skipped.
    """
    # ---- Stage 1: RMS energy ----
    rms = float(np.sqrt(np.mean(audio_chunk ** 2)))

    # ---- Stage 2: LOFAR tonal detection ----
    mean_spec = np.mean(spec_db_chunk, axis=1)
    tonals = detect_tonals_in_window(mean_spec, freqs)
    n_tonals = len(tonals)
    tonal_energy = sum(t['strength_db'] for t in tonals) if tonals else 0.0
    strongest_freq = tonals[0]['freq_hz'] if tonals else 0.0
    strongest_db = tonals[0]['strength_db'] if tonals else 0.0
    tonal_freqs = [t['freq_hz'] for t in tonals[:5]]

    # Band energy
    band_masks = {
        'low_5_20': (freqs >= 5) & (freqs < 20),
        'mid_20_80': (freqs >= 20) & (freqs < 80),
        'high_80_256': (freqs >= 80) & (freqs <= 256),
    }
    band_energy = {}
    for band_name, bmask in band_masks.items():
        if bmask.any():
            band_energy[band_name] = float(np.mean(mean_spec[bmask]))
        else:
            band_energy[band_name] = 0.0

    # Vessel score (raw — recomputed post-hoc in §7 with soft gating)
    vessel_score = (
        n_tonals * 1.0 +
        tonal_energy / 10.0 +
        strongest_db / 3.0
    )

    # ---- Stage 3: DEMON (conditional) ----
    demon_confidence = 'NONE'
    demon = _empty_demon_result()

    if rms_mean_global is not None:
        rms_ratio = rms / rms_mean_global
        if rms_ratio >= DEMON_RMS_GATE and n_tonals >= DEMON_MIN_TONALS:
            # Gate passed — run DEMON with LOFAR-informed bandpass
            demon = compute_demon_features(audio_chunk, sr, tonal_freqs)

            if demon['blade_rate_hz'] is not None:
                # Determine confidence
                if (demon['demon_harmonics'] >= 1
                        and rms_ratio >= 5.0 and n_tonals >= 3):
                    demon_confidence = 'HIGH'
                else:
                    demon_confidence = 'LOW'

    result = {
        'rms_energy': rms,
        'n_tonals': n_tonals,
        'tonal_energy': round(tonal_energy, 2),
        'strongest_tonal_hz': round(strongest_freq, 2),
        'strongest_tonal_db': round(strongest_db, 2),
        'tonal_freqs': '|'.join(f'{f:.1f}' for f in tonal_freqs),
        'band_low_5_20_db': round(band_energy['low_5_20'], 2),
        'band_mid_20_80_db': round(band_energy['mid_20_80'], 2),
        'band_high_80_256_db': round(band_energy['high_80_256'], 2),
        'vessel_score': round(vessel_score, 2),
        # Stage 3 outputs
        'blade_rate_hz': demon['blade_rate_hz'],
        'shaft_rate_hz': demon['shaft_rate_hz'],
        'est_n_blades': demon['est_n_blades'],
        'est_rpm': demon['est_rpm'],
        'demon_score': demon['demon_score'],
        'demon_harmonics': demon['demon_harmonics'],
        'demon_bp_low': demon['demon_bp_low'],
        'demon_bp_high': demon['demon_bp_high'],
        'demon_confidence': demon_confidence,
    }
    return result


print('Processing functions loaded (Stages 1 + 2 + 3)')
# Out:
# Processing functions loaded (Stages 1 + 2 + 3)

# %% [markdown]
# ## 6. Process All Files
#
# **Two-pass approach:**
# 1. **Pass 1:** Process all files through Stages 1+2 (RMS + LOFAR). This establishes the global RMS mean needed for Stage 3 gating.
# 2. **Pass 2:** Re-process elevated-energy windows through Stage 3 (DEMON) using the global RMS mean for gating.

# %%
def process_one_file(file_info, file_idx, total_files, rms_mean_global=None):
    """Process a single WAV file through the pipeline.

    If rms_mean_global is None: Stages 1+2 only (Pass 1).
    If rms_mean_global is provided: Stages 1+2+3 (Pass 2 — full pipeline).
    """
    fname = file_info['filename']
    fpath = file_info['path']
    file_start = file_info['start_ts']
    session = file_info['session']

    mode = 'Stages 1+2+3' if rms_mean_global else 'Stages 1+2'
    print(f'  [{file_idx+1}/{total_files}] session_{session} — {file_start.strftime("%d %b %H:%M")} ({mode})')

    # Load audio
    try:
        audio, sr = sf.read(fpath)
    except Exception as e:
        print(f'    ERROR reading file: {e}')
        return []
    if audio.ndim > 1:
        audio = audio[:, 0]
    duration_sec = len(audio) / sr

    print(f'    {sr} Hz, {duration_sec:.0f}s, {len(audio)/1e6:.1f}M samples')

    # ---- STFT spectrogram for full file ----
    freqs, stft_times, Sxx = compute_stft(audio, sr)
    spec_db, background = normalise_spectrogram(freqs, stft_times, Sxx)

    # ---- Optional: save full-file LOFAR spectrogram image ----
    if GENERATE_FILE_SPECTROGRAMS and rms_mean_global is not None:
        import matplotlib.dates as mdates
        from matplotlib.dates import DateFormatter as _DF, MinuteLocator as _ML

        stft_dts = np.array(
            [file_start + timedelta(seconds=float(t)) for t in stft_times],
            dtype='datetime64[ms]'
        ).astype('datetime64[us]')
        stft_mpl = mdates.date2num(stft_dts)

        fig, ax = plt.subplots(figsize=(20, 6), facecolor=STYLE['bg'])
        ax.set_facecolor(STYLE['bg'])
        freq_mask = freqs <= FREQ_MAX_HZ
        f_sub = freqs[freq_mask]

        im = ax.pcolormesh(
            stft_mpl, f_sub, spec_db[freq_mask, :],
            cmap=STYLE['cmap'], vmin=-3, vmax=20, shading='auto', rasterized=True
        )
        ax.xaxis_date()
        ax.xaxis.set_major_formatter(_DF('%H:%M'))
        ax.xaxis.set_major_locator(_ML(10))
        cbar = plt.colorbar(im, ax=ax, pad=0.01, shrink=0.9)
        cbar.set_label('dB above background', color=STYLE['text'], fontsize=10)
        cbar.ax.tick_params(colors=STYLE['text'])
        ax.set_xlabel('Time (IST)', color=STYLE['text'], fontsize=11)
        ax.set_ylabel('Frequency (Hz)', color=STYLE['text'], fontsize=11)
        ax.set_title(f'LOFAR — session_{session} — {file_start.strftime("%d %b %Y %H:%M")} IST — {sr} Hz',
                      color=STYLE['text'], fontsize=13, fontweight='bold', pad=10)
        ax.tick_params(colors=STYLE['text'])
        for s in ax.spines.values():
            s.set_color(STYLE['box_edge'])

        img_path = os.path.join(OUTPUT_DIR, f'lofar_session_{session}.png')
        plt.savefig(img_path, dpi=120, facecolor=STYLE['bg'], bbox_inches='tight')
        plt.close()

    # ---- Process 30-second analysis windows ----
    results = []
    window_samples = int(ANALYSIS_WINDOW_SEC * sr)
    hop_samples = int(ANALYSIS_HOP_SEC * sr)
    n_windows = max(1, (len(audio) - window_samples) // hop_samples + 1)

    demon_count = 0
    for wi in range(n_windows):
        start_sample = wi * hop_samples
        end_sample = start_sample + window_samples
        if end_sample > len(audio):
            break

        chunk = audio[start_sample:end_sample]
        chunk_start_sec = start_sample / sr

        # Find STFT columns that fall within this window
        stft_mask = (stft_times >= chunk_start_sec) & (stft_times < end_sample / sr)
        if not stft_mask.any():
            continue
        spec_chunk = spec_db[:, stft_mask]

        # Timestamp for this window
        ts = file_start + timedelta(seconds=chunk_start_sec)

        # Process window (Stage 3 runs if rms_mean_global provided)
        features = process_analysis_window(
            chunk, sr, spec_chunk, freqs, stft_times[stft_mask],
            rms_mean_global=rms_mean_global
        )

        if features['demon_confidence'] != 'NONE':
            demon_count += 1

        # Add metadata
        features['file'] = fname
        features['session'] = session
        features['window_idx'] = wi
        features['time_offset_sec'] = round(chunk_start_sec, 2)
        features['timestamp'] = ts.isoformat()
        features['sample_rate'] = sr

        results.append(features)

    # Persistent tonals for the full file
    persistent = detect_persistent_tonals(spec_db, freqs, stft_times)
    n_persistent = len(persistent)
    if persistent:
        top_freqs = ', '.join(f'{t["freq_hz"]:.1f}Hz ({t["duration_sec"]:.0f}s)' for t in persistent[:5])
    else:
        top_freqs = 'none'
    demon_msg = f', DEMON on {demon_count} windows' if demon_count > 0 else ''
    print(f'    {n_windows} windows, {n_persistent} persistent tonals{demon_msg}: {top_freqs}')

    # Clean up
    del audio, Sxx, spec_db
    gc.collect()

    return results


# ---- Main processing loop ----
# Pass 1: Stages 1+2 to establish global RMS baseline
# Pass 2: Full pipeline with DEMON gating

processed_sessions = set()
all_results = []

# Check for checkpoint
if os.path.exists(CHECKPOINT_FILE):
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    processed_sessions = set(ckpt.get('processed_sessions', []))
    csv_path = os.path.join(OUTPUT_DIR, 'lofar_hydrophone_results.csv')
    if os.path.exists(csv_path):
        existing = pd.read_csv(csv_path)
        # Check if DEMON columns exist (i.e., Pass 2 already done)
        if 'blade_rate_hz' in existing.columns:
            all_results = existing.to_dict('records')
            print(f'Resuming from Pass 2: {len(processed_sessions)} files, {len(all_results)} windows')
        else:
            all_results = existing.to_dict('records')
            print(f'Resuming from Pass 1: {len(processed_sessions)} files, {len(all_results)} windows')
else:
    print('Starting fresh — Pass 1 (Stages 1+2)')

start_time = _time.time()

# ---- PASS 1: Stages 1+2 (if not already done) ----
if not all_results or 'blade_rate_hz' not in all_results[0]:
    files_to_process = [f for f in all_files if f['session'] not in processed_sessions]
    print(f'Pass 1: {len(files_to_process)} files to process')
    print()

    for fi, file_info in enumerate(files_to_process):
        file_results = process_one_file(file_info, fi, len(files_to_process),
                                         rms_mean_global=None)
        all_results.extend(file_results)
        processed_sessions.add(file_info['session'])

        if (fi + 1) % 5 == 0 or fi == len(files_to_process) - 1:
            df_out = pd.DataFrame(all_results)
            csv_path = os.path.join(OUTPUT_DIR, 'lofar_hydrophone_results.csv')
            df_out.to_csv(csv_path, index=False)
            with open(CHECKPOINT_FILE, 'w') as f:
                json.dump({'processed_sessions': sorted(processed_sessions)}, f)
            elapsed = _time.time() - start_time
            rate = (fi + 1) / (elapsed / 60) if elapsed > 0 else 0
            remaining = (len(files_to_process) - fi - 1) / rate if rate > 0 else 0
            print(f'    Checkpoint: {len(processed_sessions)} files, {len(all_results)} windows, '
                  f'{elapsed/60:.1f}min elapsed, ~{remaining:.0f}min remaining')

    pass1_time = _time.time() - start_time
    print(f'\nPass 1 complete: {pass1_time/60:.1f} min')

    # Compute global RMS mean from Pass 1
    df_pass1 = pd.DataFrame(all_results)
    rms_mean_global = df_pass1['rms_energy'].mean()
    print(f'Global RMS mean: {rms_mean_global:.6f}')
    print(f'DEMON gate threshold: {DEMON_RMS_GATE}× = {rms_mean_global * DEMON_RMS_GATE:.6f}')
    n_eligible = ((df_pass1['rms_energy'] >= rms_mean_global * DEMON_RMS_GATE) &
                  (df_pass1['n_tonals'] >= DEMON_MIN_TONALS)).sum()
    print(f'Windows eligible for DEMON: {n_eligible} ({100*n_eligible/len(df_pass1):.1f}%)')

    # ---- PASS 2: Re-process ALL files with DEMON enabled ----
    print(f'\nPass 2: Full pipeline (Stages 1+2+3) — {len(all_files)} files')
    print()
    all_results = []
    processed_sessions = set()
    pass2_start = _time.time()

    for fi, file_info in enumerate(all_files):
        file_results = process_one_file(file_info, fi, len(all_files),
                                         rms_mean_global=rms_mean_global)
        all_results.extend(file_results)
        processed_sessions.add(file_info['session'])

        if (fi + 1) % 5 == 0 or fi == len(all_files) - 1:
            df_out = pd.DataFrame(all_results)
            csv_path = os.path.join(OUTPUT_DIR, 'lofar_hydrophone_results.csv')
            df_out.to_csv(csv_path, index=False)
            with open(CHECKPOINT_FILE, 'w') as f:
                json.dump({'processed_sessions': sorted(processed_sessions),
                           'pass2_complete': fi == len(all_files) - 1}, f)
            elapsed = _time.time() - pass2_start
            rate = (fi + 1) / (elapsed / 60) if elapsed > 0 else 0
            remaining = (len(all_files) - fi - 1) / rate if rate > 0 else 0
            print(f'    Checkpoint: {len(processed_sessions)} files, {len(all_results)} windows, '
                  f'{elapsed/60:.1f}min elapsed, ~{remaining:.0f}min remaining')

    pass2_time = _time.time() - pass2_start
    print(f'\nPass 2 complete: {pass2_time/60:.1f} min')

total_time = _time.time() - start_time
print(f'\n{"="*60}')
print(f'PROCESSING COMPLETE')
print(f'  Files: {len(processed_sessions)}')
print(f'  Windows: {len(all_results)}')
print(f'  Total time: {total_time/60:.1f} minutes')
print(f'  Output: {OUTPUT_DIR}')
# Out:
# Starting fresh — Pass 1 (Stages 1+2)
# Pass 1: 288 files to process
#
#   [1/288] session_1 — 30 Jan 09:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 534 persistent tonals: 26.2Hz (238s), 156.9Hz (235s), 57.9Hz (37s), 116.4Hz (61s), 104.9Hz (238s)
#   [2/288] session_2 — 30 Jan 10:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 377 persistent tonals: 116.2Hz (220s), 115.2Hz (199s), 117.9Hz (222s), 112.6Hz (199s), 124.0Hz (92s)
#   [3/288] session_3 — 30 Jan 11:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 807 persistent tonals: 159.0Hz (415s), 159.5Hz (376s), 105.2Hz (29s), 96.2Hz (46s), 84.8Hz (79s)
#   [4/288] session_4 — 30 Jan 12:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 539 persistent tonals: 163.4Hz (55s), 165.2Hz (103s), 165.2Hz (52s), 87.0Hz (61s), 166.6Hz (97s)
#   [5/288] session_5 — 30 Jan 13:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 773 persistent tonals: 111.9Hz (61s), 116.5Hz (120s), 91.5Hz (34s), 56.5Hz (59s), 164.9Hz (62s)
#     Checkpoint: 5 files, 1190 windows, 0.3min elapsed, ~14min remaining
#   [6/288] session_6 — 30 Jan 14:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 74 persistent tonals: 64.5Hz (51s), 74.5Hz (39s), 65.9Hz (51s), 78.9Hz (54s), 64.5Hz (34s)
#   [7/288] session_7 — 30 Jan 15:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 95 persistent tonals: 80.2Hz (127s), 79.2Hz (131s), 81.6Hz (114s), 77.0Hz (76s), 83.5Hz (56s)
#   [8/288] session_8 — 30 Jan 16:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 452 persistent tonals: 38.1Hz (654s), 37.2Hz (144s), 114.5Hz (57s), 114.5Hz (56s), 39.9Hz (293s)
#   [9/288] session_9 — 30 Jan 17:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 333 persistent tonals: 26.5Hz (265s), 163.9Hz (126s), 39.8Hz (265s), 185.8Hz (93s), 159.0Hz (253s)
#   [10/288] session_10 — 30 Jan 18:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 346 persistent tonals: 157.9Hz (129s), 241.5Hz (29s), 239.9Hz (36s), 85.6Hz (432s), 157.1Hz (380s)
#     Checkpoint: 10 files, 2380 windows, 0.3min elapsed, ~9min remaining
#   [11/288] session_11 — 30 Jan 19:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 517 persistent tonals: 76.4Hz (39s), 78.0Hz (93s), 75.1Hz (35s), 79.5Hz (92s), 165.8Hz (34s)
#   [12/288] session_12 — 30 Jan 20:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 845 persistent tonals: 26.8Hz (125s), 129.4Hz (37s), 109.4Hz (32s), 116.0Hz (40s), 107.0Hz (32s)
#   [13/288] session_13 — 30 Jan 21:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 25 persistent tonals: 15.1Hz (46s), 21.0Hz (50s), 15.8Hz (43s), 7.6Hz (40s), 77.0Hz (49s)
#   [14/288] session_14 — 30 Jan 22:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 291 persistent tonals: 27.8Hz (205s), 23.6Hz (78s), 23.6Hz (172s), 44.2Hz (61s), 23.4Hz (171s)
#   [15/288] session_15 — 30 Jan 23:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 10 persistent tonals: 51.4Hz (34s), 51.6Hz (274s), 51.4Hz (152s), 186.9Hz (87s), 214.0Hz (41s)
#     Checkpoint: 15 files, 3570 windows, 0.4min elapsed, ~7min remaining
#   [16/288] session_16 — 31 Jan 00:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 474 persistent tonals: 157.0Hz (195s), 157.5Hz (187s), 239.5Hz (52s), 237.8Hz (65s), 159.5Hz (152s)
#   [17/288] session_17 — 31 Jan 01:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 524 persistent tonals: 160.0Hz (86s), 72.0Hz (60s), 75.0Hz (40s), 76.6Hz (40s), 72.0Hz (40s)
#   [18/288] session_18 — 31 Jan 02:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 960 persistent tonals: 139.8Hz (254s), 139.8Hz (179s), 139.8Hz (227s), 127.8Hz (49s), 83.1Hz (205s)
#   [19/288] session_19 — 31 Jan 03:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 635 persistent tonals: 108.5Hz (73s), 105.0Hz (69s), 102.9Hz (119s), 50.2Hz (171s), 105.8Hz (139s)
#   [20/288] session_20 — 31 Jan 04:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 141 persistent tonals: 73.0Hz (163s), 73.5Hz (145s), 73.5Hz (80s), 85.1Hz (50s), 85.1Hz (40s)
#     Checkpoint: 20 files, 4760 windows, 0.4min elapsed, ~6min remaining
#   [21/288] session_21 — 31 Jan 05:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 845 persistent tonals: 131.5Hz (252s), 131.5Hz (136s), 71.9Hz (367s), 74.4Hz (334s), 130.4Hz (176s)
#   [22/288] session_22 — 31 Jan 06:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 181 persistent tonals: 66.2Hz (30s), 66.2Hz (60s), 67.8Hz (34s), 131.6Hz (149s), 66.2Hz (36s)
#   [23/288] session_23 — 31 Jan 07:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 394 persistent tonals: 74.6Hz (137s), 75.8Hz (127s), 74.6Hz (66s), 72.8Hz (75s), 72.8Hz (79s)
#   [24/288] session_24 — 31 Jan 08:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 957 persistent tonals: 159.0Hz (36s), 86.8Hz (47s), 90.9Hz (47s), 76.9Hz (46s), 104.8Hz (51s)
#   [25/288] session_25 — 31 Jan 09:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 859 persistent tonals: 148.4Hz (40s), 146.6Hz (42s), 86.5Hz (39s), 137.2Hz (171s), 88.9Hz (39s)
#     Checkpoint: 25 files, 5950 windows, 0.5min elapsed, ~5min remaining
#   [26/288] session_26 — 31 Jan 10:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 614 persistent tonals: 174.6Hz (97s), 136.9Hz (828s), 75.2Hz (66s), 93.1Hz (79s), 97.4Hz (79s)
#   [27/288] session_27 — 31 Jan 11:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 839 persistent tonals: 253.6Hz (40s), 174.8Hz (694s), 251.5Hz (40s), 249.5Hz (44s), 243.5Hz (44s)
#   [28/288] session_28 — 31 Jan 12:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 339 persistent tonals: 77.6Hz (310s), 129.8Hz (310s), 156.6Hz (310s), 155.4Hz (215s), 129.2Hz (310s)
#   [29/288] session_29 — 31 Jan 13:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 916 persistent tonals: 31.2Hz (110s), 31.5Hz (110s), 59.9Hz (79s), 57.8Hz (1220s), 75.6Hz (46s)
#   [30/288] session_30 — 31 Jan 14:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 260 persistent tonals: 114.1Hz (52s), 119.2Hz (51s), 111.6Hz (50s), 121.4Hz (50s), 117.1Hz (52s)
#     Checkpoint: 30 files, 7140 windows, 0.6min elapsed, ~5min remaining
#   [31/288] session_31 — 31 Jan 15:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 369 persistent tonals: 27.6Hz (308s), 33.9Hz (231s), 27.4Hz (338s), 30.2Hz (148s), 33.4Hz (220s)
#   [32/288] session_32 — 31 Jan 16:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 491 persistent tonals: 39.4Hz (49s), 15.0Hz (129s), 31.4Hz (141s), 31.5Hz (71s), 31.5Hz (159s)
#   [33/288] session_33 — 31 Jan 17:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 44 persistent tonals: 11.6Hz (55s), 4.4Hz (41s), 10.6Hz (51s), 8.9Hz (49s), 4.4Hz (31s)
#   [34/288] session_34 — 31 Jan 18:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 37 persistent tonals: 21.2Hz (31s), 21.2Hz (74s), 19.0Hz (63s), 21.8Hz (66s), 12.1Hz (48s)
#   [35/288] session_35 — 31 Jan 19:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 64 persistent tonals: 115.1Hz (66s), 183.2Hz (82s), 91.1Hz (35s), 92.4Hz (84s), 115.1Hz (167s)
#     Checkpoint: 35 files, 8330 windows, 0.6min elapsed, ~5min remaining
#   [36/288] session_36 — 31 Jan 20:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 187 persistent tonals: 114.8Hz (400s), 99.1Hz (106s), 57.4Hz (41s), 123.8Hz (54s), 102.9Hz (80s)
#   [37/288] session_37 — 31 Jan 21:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 766 persistent tonals: 74.1Hz (342s), 24.4Hz (72s), 56.4Hz (215s), 44.5Hz (263s), 36.0Hz (906s)
#   [38/288] session_38 — 31 Jan 22:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 68 persistent tonals: 60.4Hz (32s), 21.4Hz (32s), 74.4Hz (32s), 212.5Hz (60s), 225.8Hz (73s)
#   [39/288] session_39 — 31 Jan 23:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 7 persistent tonals: 119.6Hz (44s), 99.8Hz (70s), 12.9Hz (36s), 17.1Hz (73s), 20.8Hz (42s)
#   [40/288] session_40 — 01 Feb 00:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 18 persistent tonals: 97.6Hz (31s), 97.6Hz (77s), 105.8Hz (42s), 138.0Hz (70s), 109.2Hz (35s)
#     Checkpoint: 40 files, 9520 windows, 0.7min elapsed, ~4min remaining
#   [41/288] session_41 — 01 Feb 01:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 17 persistent tonals: 138.5Hz (52s), 52.0Hz (154s), 107.8Hz (35s), 249.5Hz (30s), 251.9Hz (30s)
#   [42/288] session_42 — 01 Feb 02:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 20 persistent tonals: 38.8Hz (49s), 59.0Hz (101s), 74.9Hz (98s), 205.1Hz (76s), 205.1Hz (57s)
#   [43/288] session_43 — 01 Feb 03:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 17 persistent tonals: 34.6Hz (45s), 29.1Hz (31s), 32.2Hz (40s), 17.4Hz (29s), 40.5Hz (30s)
#   [44/288] session_44 — 01 Feb 04:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 2 persistent tonals: 83.9Hz (95s), 83.0Hz (60s)
#   [45/288] session_45 — 01 Feb 05:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 305 persistent tonals: 138.9Hz (220s), 138.9Hz (161s), 53.0Hz (548s), 105.4Hz (39s), 53.5Hz (353s)
#     Checkpoint: 45 files, 10710 windows, 0.8min elapsed, ~4min remaining
#   [46/288] session_46 — 01 Feb 06:04 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 921 persistent tonals: 119.1Hz (181s), 53.2Hz (866s), 106.1Hz (775s), 158.5Hz (523s), 176.9Hz (662s)
#   [47/288] session_47 — 01 Feb 07:04 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 471 persistent tonals: 70.8Hz (389s), 165.0Hz (598s), 243.5Hz (71s), 229.4Hz (214s), 241.5Hz (97s)
#   [48/288] session_48 — 01 Feb 08:04 (Stages 1+2)
#     512 Hz, 1939s, 1.0M samples
#     128 windows, 455 persistent tonals: 93.9Hz (279s), 164.5Hz (260s), 117.5Hz (240s), 45.8Hz (220s), 70.4Hz (401s)
#   [49/288] session_49 — 01 Feb 08:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 729 persistent tonals: 116.4Hz (70s), 117.8Hz (77s), 112.8Hz (29s), 93.0Hz (44s), 115.2Hz (70s)
#   [50/288] session_50 — 01 Feb 09:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 840 persistent tonals: 201.4Hz (47s), 158.5Hz (137s), 68.1Hz (512s), 158.5Hz (189s), 158.5Hz (92s)
#     Checkpoint: 50 files, 11790 windows, 0.8min elapsed, ~4min remaining
#   [51/288] session_51 — 01 Feb 10:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 379 persistent tonals: 194.6Hz (70s), 127.4Hz (59s), 128.0Hz (113s), 127.4Hz (64s), 128.0Hz (61s)
#   [52/288] session_52 — 01 Feb 11:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 482 persistent tonals: 83.6Hz (154s), 83.2Hz (143s), 167.4Hz (98s), 74.0Hz (145s), 180.5Hz (157s)
#   [53/288] session_53 — 01 Feb 12:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 195 persistent tonals: 18.8Hz (60s), 20.8Hz (69s), 33.6Hz (65s), 8.5Hz (65s), 36.5Hz (65s)
#   [54/288] session_54 — 01 Feb 13:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 31 persistent tonals: 34.2Hz (77s), 25.2Hz (45s), 19.9Hz (37s), 25.8Hz (45s), 10.4Hz (42s)
#   [55/288] session_55 — 01 Feb 14:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 10 persistent tonals: 10.5Hz (102s), 8.0Hz (133s), 7.2Hz (131s), 11.8Hz (100s), 13.5Hz (118s)
#     Checkpoint: 55 files, 12980 windows, 0.9min elapsed, ~4min remaining
#   [56/288] session_56 — 01 Feb 15:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 8 persistent tonals: 51.0Hz (241s), 18.6Hz (31s), 51.0Hz (29s), 100.1Hz (30s), 98.6Hz (56s)
#   [57/288] session_57 — 01 Feb 16:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 6 persistent tonals: 49.2Hz (59s), 45.1Hz (60s), 46.6Hz (33s), 45.1Hz (33s), 4.9Hz (32s)
#   [58/288] session_58 — 01 Feb 17:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 309 persistent tonals: 48.2Hz (56s), 34.0Hz (209s), 68.0Hz (208s), 72.1Hz (50s), 27.1Hz (44s)
#   [59/288] session_59 — 01 Feb 18:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 207 persistent tonals: 59.9Hz (545s), 110.9Hz (30s), 63.1Hz (96s), 59.4Hz (78s), 8.0Hz (68s)
#   [60/288] session_60 — 01 Feb 19:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 549 persistent tonals: 145.2Hz (321s), 72.5Hz (507s), 67.0Hz (436s), 145.5Hz (351s), 134.0Hz (426s)
#     Checkpoint: 60 files, 14170 windows, 0.9min elapsed, ~4min remaining
#   [61/288] session_61 — 01 Feb 20:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 43 persistent tonals: 93.8Hz (67s), 5.6Hz (100s), 4.9Hz (124s), 9.2Hz (47s), 22.2Hz (31s)
#   [62/288] session_62 — 01 Feb 21:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 237 persistent tonals: 71.1Hz (44s), 52.0Hz (148s), 54.6Hz (205s), 85.2Hz (29s), 45.4Hz (69s)
#   [63/288] session_63 — 01 Feb 22:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 9 persistent tonals: 6.6Hz (42s), 4.2Hz (47s), 139.6Hz (35s), 88.9Hz (43s), 88.9Hz (52s)
#   [64/288] session_64 — 01 Feb 23:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 0 persistent tonals: none
#   [65/288] session_65 — 02 Feb 00:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 22 persistent tonals: 106.0Hz (38s), 113.6Hz (52s), 122.1Hz (264s), 35.9Hz (29s), 112.5Hz (50s)
#     Checkpoint: 65 files, 15360 windows, 1.0min elapsed, ~3min remaining
#   [66/288] session_66 — 02 Feb 01:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 38 persistent tonals: 125.6Hz (49s), 125.1Hz (47s), 104.8Hz (78s), 125.1Hz (41s), 125.1Hz (34s)
#   [67/288] session_67 — 02 Feb 02:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 41 persistent tonals: 75.9Hz (55s), 75.9Hz (72s), 75.1Hz (64s), 75.1Hz (263s), 75.1Hz (36s)
#   [68/288] session_68 — 02 Feb 03:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 469 persistent tonals: 76.8Hz (511s), 153.1Hz (101s), 75.2Hz (424s), 77.5Hz (438s), 73.2Hz (357s)
#   [69/288] session_69 — 02 Feb 04:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 322 persistent tonals: 49.2Hz (30s), 72.2Hz (721s), 72.2Hz (135s), 44.5Hz (34s), 42.0Hz (39s)
#   [70/288] session_70 — 02 Feb 05:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 62 persistent tonals: 72.8Hz (145s), 85.1Hz (76s), 85.1Hz (150s), 173.6Hz (41s), 76.0Hz (31s)
#     Checkpoint: 70 files, 16550 windows, 1.1min elapsed, ~3min remaining
#   [71/288] session_71 — 02 Feb 06:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 102 persistent tonals: 160.5Hz (101s), 163.9Hz (32s), 166.5Hz (63s), 166.5Hz (113s), 166.5Hz (174s)
#   [72/288] session_72 — 02 Feb 07:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 180 persistent tonals: 107.1Hz (100s), 57.5Hz (71s), 95.9Hz (37s), 166.5Hz (65s), 166.5Hz (31s)
#   [73/288] session_73 — 02 Feb 08:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 968 persistent tonals: 21.9Hz (29s), 113.1Hz (697s), 113.5Hz (640s), 15.2Hz (33s), 165.1Hz (290s)
#   [74/288] session_74 — 02 Feb 09:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 200 persistent tonals: 46.8Hz (253s), 70.1Hz (260s), 187.1Hz (166s), 108.8Hz (95s), 216.4Hz (33s)
#   [75/288] session_75 — 02 Feb 10:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 211 persistent tonals: 26.1Hz (32s), 99.9Hz (219s), 87.2Hz (92s), 80.9Hz (123s), 99.9Hz (81s)
#     Checkpoint: 75 files, 17740 windows, 1.1min elapsed, ~3min remaining
#   [76/288] session_76 — 02 Feb 11:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 79 persistent tonals: 187.4Hz (167s), 179.4Hz (56s), 95.9Hz (99s), 134.1Hz (77s), 115.1Hz (135s)
#   [77/288] session_77 — 02 Feb 12:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 210 persistent tonals: 62.1Hz (30s), 35.6Hz (54s), 28.4Hz (55s), 32.5Hz (61s), 35.2Hz (70s)
#   [78/288] session_78 — 02 Feb 13:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 530 persistent tonals: 112.8Hz (1014s), 25.2Hz (143s), 113.5Hz (784s), 98.8Hz (514s), 70.8Hz (539s)
#   [79/288] session_79 — 02 Feb 14:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 23 persistent tonals: 66.4Hz (487s), 61.4Hz (307s), 74.2Hz (77s), 61.5Hz (34s), 61.5Hz (60s)
#   [80/288] session_80 — 02 Feb 15:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 2 persistent tonals: 6.9Hz (41s), 40.2Hz (39s)
#     Checkpoint: 80 files, 18930 windows, 1.2min elapsed, ~3min remaining
#   [81/288] session_81 — 02 Feb 16:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 293 persistent tonals: 184.4Hz (100s), 92.6Hz (180s), 93.6Hz (67s), 44.0Hz (159s), 183.4Hz (102s)
#   [82/288] session_82 — 02 Feb 17:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 531 persistent tonals: 115.9Hz (130s), 148.0Hz (44s), 115.9Hz (47s), 143.5Hz (44s), 223.0Hz (58s)
#   [83/288] session_83 — 02 Feb 18:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 468 persistent tonals: 85.6Hz (154s), 84.9Hz (320s), 106.6Hz (299s), 88.0Hz (287s), 106.6Hz (265s)
#   [84/288] session_84 — 02 Feb 19:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 849 persistent tonals: 177.5Hz (83s), 106.6Hz (756s), 177.5Hz (767s), 46.1Hz (1180s), 82.8Hz (367s)
#   [85/288] session_85 — 02 Feb 20:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 116 persistent tonals: 27.0Hz (61s), 64.6Hz (56s), 53.5Hz (61s), 53.1Hz (61s), 27.8Hz (53s)
#     Checkpoint: 85 files, 20120 windows, 1.2min elapsed, ~3min remaining
#   [86/288] session_86 — 02 Feb 21:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 656 persistent tonals: 119.8Hz (573s), 139.8Hz (153s), 47.6Hz (100s), 150.2Hz (143s), 100.2Hz (439s)
#   [87/288] session_87 — 02 Feb 22:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 585 persistent tonals: 119.9Hz (483s), 99.8Hz (483s), 149.5Hz (429s), 89.9Hz (334s), 149.4Hz (337s)
#   [88/288] session_88 — 02 Feb 23:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 826 persistent tonals: 95.0Hz (724s), 41.2Hz (477s), 189.9Hz (861s), 237.5Hz (40s), 189.4Hz (543s)
#   [89/288] session_89 — 03 Feb 00:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 193 persistent tonals: 117.2Hz (51s), 105.4Hz (29s), 117.2Hz (112s), 117.5Hz (41s), 127.4Hz (97s)
#   [90/288] session_90 — 03 Feb 01:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 215 persistent tonals: 145.5Hz (42s), 145.5Hz (49s), 52.8Hz (890s), 145.4Hz (37s), 215.4Hz (277s)
#     Checkpoint: 90 files, 21310 windows, 1.3min elapsed, ~3min remaining
#   [91/288] session_91 — 03 Feb 02:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 569 persistent tonals: 36.2Hz (170s), 145.4Hz (384s), 137.0Hz (405s), 145.5Hz (380s), 44.9Hz (154s)
#   [92/288] session_92 — 03 Feb 03:51 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 249 persistent tonals: 84.6Hz (527s), 40.6Hz (185s), 83.4Hz (142s), 85.5Hz (105s), 4.8Hz (34s)
#   [93/288] session_93 — 03 Feb 04:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 778 persistent tonals: 245.5Hz (44s), 247.6Hz (42s), 243.8Hz (96s), 241.5Hz (153s), 241.5Hz (34s)
#   [94/288] session_94 — 03 Feb 05:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 875 persistent tonals: 31.9Hz (493s), 27.1Hz (482s), 43.2Hz (722s), 37.6Hz (706s), 124.0Hz (506s)
#   [95/288] session_95 — 03 Feb 06:51 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 374 persistent tonals: 80.6Hz (317s), 56.5Hz (158s), 47.1Hz (146s), 65.9Hz (172s), 72.5Hz (612s)
#     Checkpoint: 95 files, 22500 windows, 1.4min elapsed, ~3min remaining
#   [96/288] session_96 — 03 Feb 07:51 (Stages 1+2)
#     512 Hz, 3590s, 1.8M samples
#     238 windows, 187 persistent tonals: 116.9Hz (45s), 113.5Hz (45s), 113.4Hz (45s), 118.2Hz (44s), 110.2Hz (45s)
#   [97/288] session_97 — 03 Feb 08:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 777 persistent tonals: 83.4Hz (55s), 79.8Hz (51s), 83.9Hz (59s), 99.2Hz (32s), 112.9Hz (95s)
#   [98/288] session_98 — 03 Feb 09:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 1144 persistent tonals: 46.2Hz (75s), 102.9Hz (478s), 53.0Hz (39s), 43.1Hz (461s), 20.6Hz (832s)
#   [99/288] session_99 — 03 Feb 10:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 1008 persistent tonals: 111.9Hz (389s), 47.0Hz (162s), 21.9Hz (277s), 89.5Hz (466s), 89.4Hz (433s)
#   [100/288] session_100 — 03 Feb 11:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 606 persistent tonals: 131.4Hz (218s), 197.9Hz (179s), 131.6Hz (465s), 65.9Hz (1075s), 177.9Hz (51s)
#     Checkpoint: 100 files, 23690 windows, 1.4min elapsed, ~3min remaining
#   [101/288] session_101 — 03 Feb 12:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 573 persistent tonals: 130.9Hz (516s), 66.6Hz (435s), 131.9Hz (649s), 164.2Hz (230s), 98.6Hz (305s)
#   [102/288] session_102 — 03 Feb 13:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 245 persistent tonals: 47.1Hz (182s), 40.4Hz (148s), 65.4Hz (84s), 47.5Hz (92s), 70.4Hz (148s)
#   [103/288] session_103 — 03 Feb 14:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 548 persistent tonals: 109.1Hz (468s), 65.5Hz (1126s), 87.2Hz (289s), 65.4Hz (1138s), 152.6Hz (317s)
#   [104/288] session_104 — 03 Feb 15:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 98 persistent tonals: 17.0Hz (43s), 23.2Hz (33s), 5.4Hz (45s), 6.5Hz (44s), 7.8Hz (42s)
#   [105/288] session_105 — 03 Feb 16:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 112 persistent tonals: 161.6Hz (90s), 46.5Hz (32s), 17.8Hz (72s), 52.2Hz (131s), 27.8Hz (69s)
#     Checkpoint: 105 files, 24880 windows, 1.5min elapsed, ~3min remaining
#   [106/288] session_106 — 03 Feb 17:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 336 persistent tonals: 102.6Hz (29s), 99.9Hz (33s), 103.9Hz (29s), 92.0Hz (29s), 98.8Hz (33s)
#   [107/288] session_107 — 03 Feb 18:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 500 persistent tonals: 107.5Hz (44s), 120.9Hz (40s), 91.8Hz (29s), 95.2Hz (45s), 91.4Hz (42s)
#   [108/288] session_108 — 03 Feb 19:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 896 persistent tonals: 76.9Hz (846s), 62.9Hz (502s), 56.1Hz (924s), 59.2Hz (949s), 38.5Hz (277s)
#   [109/288] session_109 — 03 Feb 20:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 120 persistent tonals: 17.4Hz (40s), 18.2Hz (43s), 128.5Hz (60s), 30.9Hz (38s), 128.5Hz (94s)
#   [110/288] session_110 — 03 Feb 21:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 389 persistent tonals: 125.9Hz (42s), 134.2Hz (93s), 124.8Hz (33s), 159.8Hz (72s), 124.8Hz (43s)
#     Checkpoint: 110 files, 26070 windows, 1.6min elapsed, ~3min remaining
#   [111/288] session_111 — 03 Feb 22:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 162 persistent tonals: 134.1Hz (52s), 112.8Hz (44s), 202.5Hz (44s), 112.8Hz (110s), 118.5Hz (36s)
#   [112/288] session_112 — 03 Feb 23:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 275 persistent tonals: 83.8Hz (30s), 92.1Hz (57s), 93.8Hz (29s), 89.6Hz (57s), 96.6Hz (142s)
#   [113/288] session_113 — 04 Feb 00:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 342 persistent tonals: 132.0Hz (138s), 120.1Hz (155s), 134.9Hz (138s), 137.0Hz (137s), 138.8Hz (144s)
#   [114/288] session_114 — 04 Feb 01:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 217 persistent tonals: 70.8Hz (32s), 68.8Hz (29s), 72.4Hz (32s), 84.8Hz (31s), 92.6Hz (38s)
#   [115/288] session_115 — 04 Feb 02:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 71 persistent tonals: 4.6Hz (169s), 75.4Hz (36s), 5.6Hz (168s), 75.9Hz (47s), 75.9Hz (55s)
#     Checkpoint: 115 files, 27260 windows, 1.6min elapsed, ~2min remaining
#   [116/288] session_116 — 04 Feb 03:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 84 persistent tonals: 75.2Hz (34s), 6.1Hz (48s), 75.2Hz (30s), 4.6Hz (327s), 75.5Hz (31s)
#   [117/288] session_117 — 04 Feb 04:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 135 persistent tonals: 17.5Hz (128s), 21.0Hz (125s), 23.1Hz (117s), 9.4Hz (161s), 27.2Hz (128s)
#   [118/288] session_118 — 04 Feb 05:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 47 persistent tonals: 14.1Hz (41s), 13.2Hz (39s), 20.4Hz (38s), 6.8Hz (42s), 18.5Hz (44s)
#   [119/288] session_119 — 04 Feb 06:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 437 persistent tonals: 17.2Hz (29s), 13.6Hz (29s), 18.6Hz (32s), 20.2Hz (29s), 13.4Hz (29s)
#   [120/288] session_120 — 04 Feb 07:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 924 persistent tonals: 151.5Hz (340s), 35.4Hz (155s), 80.6Hz (726s), 141.1Hz (674s), 201.6Hz (706s)
#     Checkpoint: 120 files, 28450 windows, 1.7min elapsed, ~2min remaining
#   [121/288] session_121 — 04 Feb 08:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 1178 persistent tonals: 123.6Hz (621s), 82.4Hz (492s), 72.1Hz (580s), 103.2Hz (540s), 123.4Hz (577s)
#   [122/288] session_122 — 04 Feb 09:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 473 persistent tonals: 100.1Hz (66s), 25.9Hz (30s), 82.8Hz (335s), 82.8Hz (302s), 74.1Hz (89s)
#   [123/288] session_123 — 04 Feb 10:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 1232 persistent tonals: 35.0Hz (91s), 35.0Hz (314s), 165.1Hz (106s), 161.4Hz (69s), 95.8Hz (96s)
#   [124/288] session_124 — 04 Feb 11:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 495 persistent tonals: 69.2Hz (536s), 103.8Hz (456s), 115.5Hz (465s), 173.0Hz (904s), 115.4Hz (796s)
#   [125/288] session_125 — 04 Feb 12:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 1017 persistent tonals: 191.2Hz (214s), 173.5Hz (310s), 198.2Hz (140s), 138.8Hz (524s), 161.6Hz (395s)
#     Checkpoint: 125 files, 29640 windows, 1.8min elapsed, ~2min remaining
#   [126/288] session_126 — 04 Feb 13:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 612 persistent tonals: 70.9Hz (634s), 47.1Hz (276s), 141.8Hz (726s), 118.0Hz (573s), 59.0Hz (207s)
#   [127/288] session_127 — 04 Feb 14:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 925 persistent tonals: 22.2Hz (792s), 102.6Hz (369s), 171.1Hz (163s), 136.6Hz (504s), 137.8Hz (225s)
#   [128/288] session_128 — 04 Feb 15:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 776 persistent tonals: 21.9Hz (291s), 112.1Hz (578s), 100.9Hz (526s), 134.5Hz (720s), 156.6Hz (434s)
#   [129/288] session_129 — 04 Feb 16:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 107 persistent tonals: 91.5Hz (92s), 67.6Hz (98s), 30.2Hz (75s), 182.9Hz (32s), 17.9Hz (76s)
#   [130/288] session_130 — 04 Feb 17:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 766 persistent tonals: 65.1Hz (735s), 48.9Hz (762s), 39.4Hz (1423s), 53.1Hz (738s), 61.0Hz (595s)
#     Checkpoint: 130 files, 30830 windows, 1.9min elapsed, ~2min remaining
#   [131/288] session_131 — 04 Feb 18:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 64 persistent tonals: 61.6Hz (49s), 20.2Hz (60s), 34.2Hz (72s), 15.5Hz (64s), 18.5Hz (65s)
#   [132/288] session_132 — 04 Feb 19:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 269 persistent tonals: 164.6Hz (171s), 125.2Hz (222s), 197.6Hz (74s), 70.9Hz (34s), 131.5Hz (65s)
#   [133/288] session_133 — 04 Feb 20:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 459 persistent tonals: 65.8Hz (372s), 65.8Hz (78s), 164.4Hz (101s), 197.5Hz (149s), 65.8Hz (234s)
#   [134/288] session_134 — 04 Feb 21:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 408 persistent tonals: 87.4Hz (121s), 118.9Hz (143s), 87.4Hz (59s), 118.9Hz (42s), 153.2Hz (48s)
#   [135/288] session_135 — 04 Feb 22:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 715 persistent tonals: 8.1Hz (68s), 6.9Hz (51s), 10.5Hz (59s), 132.8Hz (213s), 154.8Hz (136s)
#     Checkpoint: 135 files, 32020 windows, 1.9min elapsed, ~2min remaining
#   [136/288] session_136 — 04 Feb 23:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 742 persistent tonals: 50.1Hz (344s), 50.1Hz (497s), 75.6Hz (441s), 155.1Hz (212s), 50.1Hz (361s)
#   [137/288] session_137 — 05 Feb 00:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 653 persistent tonals: 26.4Hz (57s), 28.0Hz (85s), 39.2Hz (82s), 133.9Hz (605s), 39.5Hz (96s)
#   [138/288] session_138 — 05 Feb 01:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 130 persistent tonals: 68.6Hz (71s), 71.1Hz (117s), 219.4Hz (50s), 68.6Hz (48s), 196.0Hz (51s)
#   [139/288] session_139 — 05 Feb 02:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 673 persistent tonals: 56.4Hz (576s), 62.0Hz (520s), 65.6Hz (539s), 60.0Hz (396s), 65.1Hz (434s)
#   [140/288] session_140 — 05 Feb 03:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 931 persistent tonals: 73.5Hz (597s), 73.0Hz (535s), 149.2Hz (103s), 233.4Hz (33s), 153.2Hz (46s)
#     Checkpoint: 140 files, 33210 windows, 2.0min elapsed, ~2min remaining
#   [141/288] session_141 — 05 Feb 04:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 476 persistent tonals: 86.4Hz (298s), 81.5Hz (249s), 85.0Hz (383s), 81.2Hz (231s), 156.6Hz (162s)
#   [142/288] session_142 — 05 Feb 05:54 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 10 persistent tonals: 75.2Hz (191s), 75.2Hz (51s), 75.2Hz (33s), 75.2Hz (49s), 75.2Hz (123s)
#   [143/288] session_143 — 05 Feb 06:54 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 18 persistent tonals: 166.5Hz (39s), 164.6Hz (55s), 167.5Hz (41s), 163.4Hz (37s), 35.9Hz (75s)
#   [144/288] session_144 — 05 Feb 07:54 (Stages 1+2)
#     512 Hz, 312s, 0.2M samples
#     19 windows, 11 persistent tonals: 97.5Hz (30s), 78.1Hz (29s), 95.5Hz (45s), 95.2Hz (41s), 56.5Hz (37s)
#   [145/288] session_145 — 05 Feb 08:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 744 persistent tonals: 39.2Hz (1141s), 32.6Hz (959s), 39.5Hz (1110s), 33.5Hz (1068s), 37.4Hz (1211s)
#     Checkpoint: 145 files, 34181 windows, 2.1min elapsed, ~2min remaining
#   [146/288] session_146 — 05 Feb 09:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 195 persistent tonals: 130.9Hz (217s), 196.2Hz (180s), 130.9Hz (175s), 120.0Hz (30s), 130.9Hz (370s)
#   [147/288] session_147 — 05 Feb 10:00 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 590 persistent tonals: 196.0Hz (77s), 196.0Hz (481s), 228.2Hz (43s), 130.9Hz (144s), 130.9Hz (391s)
#   [148/288] session_148 — 05 Feb 11:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 32 persistent tonals: 26.0Hz (32s), 25.0Hz (32s), 23.2Hz (32s), 21.4Hz (32s), 17.5Hz (32s)
#   [149/288] session_149 — 05 Feb 12:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 828 persistent tonals: 112.5Hz (234s), 112.5Hz (162s), 251.5Hz (36s), 253.5Hz (36s), 249.5Hz (36s)
#   [150/288] session_150 — 05 Feb 13:00 (Stages 1+2)
#     512 Hz, 3064s, 1.6M samples
#     203 windows, 45 persistent tonals: 36.4Hz (49s), 25.1Hz (45s), 38.6Hz (56s), 25.5Hz (46s), 39.8Hz (47s)
#     Checkpoint: 150 files, 35336 windows, 2.1min elapsed, ~2min remaining
#   [151/288] session_151 — 05 Feb 14:00 (Stages 1+2)
#     512 Hz, 2986s, 1.5M samples
#     198 windows, 73 persistent tonals: 130.4Hz (90s), 42.8Hz (42s), 44.8Hz (41s), 18.1Hz (35s), 23.0Hz (38s)
#   [152/288] session_152 — 05 Feb 15:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 645 persistent tonals: 67.4Hz (320s), 91.6Hz (310s), 75.0Hz (295s), 83.0Hz (506s), 99.6Hz (332s)
#   [153/288] session_153 — 05 Feb 16:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 575 persistent tonals: 132.5Hz (550s), 66.4Hz (81s), 33.5Hz (323s), 124.4Hz (215s), 41.8Hz (282s)
#   [154/288] session_154 — 05 Feb 17:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 706 persistent tonals: 30.0Hz (127s), 30.0Hz (328s), 122.6Hz (40s), 202.1Hz (85s), 31.8Hz (36s)
#   [155/288] session_155 — 05 Feb 18:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 710 persistent tonals: 182.2Hz (500s), 54.1Hz (53s), 55.9Hz (107s), 91.4Hz (42s), 183.8Hz (404s)
#     Checkpoint: 155 files, 36486 windows, 2.2min elapsed, ~2min remaining
#   [156/288] session_156 — 05 Feb 19:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 407 persistent tonals: 69.4Hz (195s), 84.8Hz (86s), 85.6Hz (63s), 115.5Hz (154s), 138.6Hz (296s)
#   [157/288] session_157 — 05 Feb 20:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 603 persistent tonals: 245.5Hz (90s), 69.4Hz (552s), 247.5Hz (44s), 241.5Hz (124s), 249.5Hz (39s)
#   [158/288] session_158 — 05 Feb 21:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 488 persistent tonals: 58.8Hz (1083s), 59.5Hz (821s), 61.8Hz (650s), 59.5Hz (158s), 57.1Hz (370s)
#   [159/288] session_159 — 05 Feb 22:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 332 persistent tonals: 75.0Hz (124s), 51.2Hz (130s), 46.5Hz (37s), 70.4Hz (38s), 125.2Hz (125s)
#   [160/288] session_160 — 05 Feb 23:00 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 42 persistent tonals: 96.1Hz (49s), 190.9Hz (97s), 52.4Hz (278s), 68.9Hz (56s), 27.2Hz (42s)
#     Checkpoint: 160 files, 37676 windows, 2.3min elapsed, ~2min remaining
#   [161/288] session_161 — 06 Feb 00:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 303 persistent tonals: 107.0Hz (105s), 107.0Hz (68s), 129.0Hz (53s), 107.0Hz (158s), 126.0Hz (66s)
#   [162/288] session_162 — 06 Feb 01:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 50 persistent tonals: 23.8Hz (37s), 21.4Hz (35s), 25.5Hz (37s), 18.0Hz (37s), 23.1Hz (35s)
#   [163/288] session_163 — 06 Feb 02:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 380 persistent tonals: 81.5Hz (290s), 64.8Hz (346s), 65.6Hz (345s), 75.6Hz (292s), 72.2Hz (352s)
#   [164/288] session_164 — 06 Feb 03:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 1231 persistent tonals: 38.4Hz (938s), 35.1Hz (350s), 36.8Hz (756s), 40.2Hz (996s), 35.1Hz (264s)
#   [165/288] session_165 — 06 Feb 04:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 313 persistent tonals: 47.0Hz (39s), 73.5Hz (68s), 73.2Hz (59s), 73.5Hz (54s), 73.5Hz (56s)
#     Checkpoint: 165 files, 38866 windows, 2.4min elapsed, ~2min remaining
#   [166/288] session_166 — 06 Feb 05:00 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 212 persistent tonals: 137.9Hz (161s), 81.6Hz (146s), 80.4Hz (147s), 77.8Hz (34s), 172.4Hz (47s)
#   [167/288] session_167 — 06 Feb 06:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 366 persistent tonals: 161.5Hz (60s), 72.2Hz (79s), 164.0Hz (61s), 81.6Hz (38s), 71.2Hz (95s)
#   [168/288] session_168 — 06 Feb 07:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 987 persistent tonals: 42.2Hz (425s), 130.0Hz (710s), 140.8Hz (582s), 151.5Hz (84s), 108.2Hz (308s)
#   [169/288] session_169 — 06 Feb 08:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 646 persistent tonals: 88.4Hz (506s), 150.0Hz (162s), 211.8Hz (569s), 42.2Hz (333s), 105.1Hz (358s)
#   [170/288] session_170 — 06 Feb 09:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 422 persistent tonals: 77.2Hz (198s), 77.5Hz (42s), 122.0Hz (229s), 65.4Hz (174s), 146.5Hz (174s)
#     Checkpoint: 170 files, 40056 windows, 2.4min elapsed, ~2min remaining
#   [171/288] session_171 — 06 Feb 10:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 739 persistent tonals: 80.4Hz (110s), 81.5Hz (114s), 81.5Hz (146s), 64.5Hz (465s), 52.5Hz (201s)
#   [172/288] session_172 — 06 Feb 11:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 331 persistent tonals: 72.8Hz (206s), 14.0Hz (56s), 38.4Hz (157s), 12.1Hz (67s), 19.2Hz (67s)
#   [173/288] session_173 — 06 Feb 12:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 618 persistent tonals: 132.6Hz (436s), 33.4Hz (97s), 133.8Hz (204s), 67.1Hz (77s), 99.2Hz (138s)
#   [174/288] session_174 — 06 Feb 13:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 798 persistent tonals: 66.6Hz (132s), 94.1Hz (69s), 53.9Hz (121s), 80.6Hz (104s), 75.9Hz (90s)
#   [175/288] session_175 — 06 Feb 14:00 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 479 persistent tonals: 80.5Hz (233s), 10.6Hz (91s), 35.2Hz (205s), 125.5Hz (153s), 99.0Hz (224s)
#     Checkpoint: 175 files, 41246 windows, 2.5min elapsed, ~2min remaining
#   [176/288] session_176 — 06 Feb 15:00 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 675 persistent tonals: 42.2Hz (189s), 45.2Hz (143s), 45.2Hz (109s), 67.4Hz (102s), 135.1Hz (128s)
#   [177/288] session_177 — 06 Feb 16:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 911 persistent tonals: 44.2Hz (137s), 132.9Hz (227s), 41.5Hz (142s), 140.9Hz (334s), 132.9Hz (238s)
#   [178/288] session_178 — 06 Feb 17:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 789 persistent tonals: 104.0Hz (482s), 93.5Hz (404s), 187.6Hz (669s), 114.6Hz (220s), 187.4Hz (453s)
#   [179/288] session_179 — 06 Feb 18:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 896 persistent tonals: 96.8Hz (482s), 29.0Hz (507s), 77.6Hz (152s), 48.4Hz (839s), 58.1Hz (374s)
#   [180/288] session_180 — 06 Feb 19:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 390 persistent tonals: 55.5Hz (750s), 61.8Hz (627s), 49.0Hz (601s), 55.4Hz (481s), 61.4Hz (668s)
#     Checkpoint: 180 files, 42436 windows, 2.6min elapsed, ~2min remaining
#   [181/288] session_181 — 06 Feb 20:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 116 persistent tonals: 73.0Hz (397s), 70.1Hz (106s), 70.1Hz (84s), 60.6Hz (262s), 59.4Hz (178s)
#   [182/288] session_182 — 06 Feb 21:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 770 persistent tonals: 129.2Hz (490s), 62.2Hz (503s), 124.6Hz (501s), 145.4Hz (92s), 193.6Hz (168s)
#   [183/288] session_183 — 06 Feb 22:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 344 persistent tonals: 51.6Hz (118s), 55.2Hz (63s), 41.2Hz (43s), 80.2Hz (40s), 28.0Hz (50s)
#   [184/288] session_184 — 06 Feb 23:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 124 persistent tonals: 166.4Hz (33s), 81.8Hz (401s), 164.1Hz (35s), 157.0Hz (111s), 80.5Hz (238s)
#   [185/288] session_185 — 07 Feb 00:00 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 737 persistent tonals: 249.5Hz (37s), 251.5Hz (37s), 253.6Hz (37s), 41.8Hz (1057s), 247.5Hz (37s)
#     Checkpoint: 185 files, 43626 windows, 2.6min elapsed, ~1min remaining
#   [186/288] session_186 — 07 Feb 01:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 886 persistent tonals: 57.5Hz (449s), 65.6Hz (1025s), 68.4Hz (1065s), 60.8Hz (520s), 64.5Hz (831s)
#   [187/288] session_187 — 07 Feb 02:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 436 persistent tonals: 9.8Hz (64s), 6.2Hz (68s), 13.2Hz (69s), 13.6Hz (53s), 21.2Hz (69s)
#   [188/288] session_188 — 07 Feb 03:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 464 persistent tonals: 124.9Hz (44s), 129.6Hz (31s), 107.6Hz (41s), 129.6Hz (50s), 128.6Hz (133s)
#   [189/288] session_189 — 07 Feb 04:00 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 189 persistent tonals: 5.4Hz (52s), 6.4Hz (52s), 5.4Hz (36s), 7.8Hz (52s), 6.4Hz (36s)
#   [190/288] session_190 — 07 Feb 05:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 62 persistent tonals: 31.8Hz (235s), 76.6Hz (72s), 81.9Hz (606s), 76.6Hz (92s), 83.8Hz (35s)
#     Checkpoint: 190 files, 44816 windows, 2.7min elapsed, ~1min remaining
#   [191/288] session_191 — 07 Feb 06:00 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 97 persistent tonals: 115.0Hz (137s), 57.5Hz (616s), 115.0Hz (440s), 115.0Hz (239s), 57.5Hz (279s)
#   [192/288] session_192 — 07 Feb 07:00 (Stages 1+2)
#     512 Hz, 3573s, 1.8M samples
#     237 windows, 574 persistent tonals: 45.8Hz (633s), 160.1Hz (570s), 68.6Hz (558s), 137.1Hz (568s), 114.2Hz (483s)
#   [193/288] session_193 — 07 Feb 08:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 670 persistent tonals: 58.1Hz (118s), 96.9Hz (113s), 98.6Hz (41s), 83.8Hz (106s), 90.4Hz (45s)
#   [194/288] session_194 — 07 Feb 09:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 147 persistent tonals: 180.6Hz (35s), 182.8Hz (33s), 186.9Hz (34s), 177.0Hz (33s), 173.1Hz (33s)
#   [195/288] session_195 — 07 Feb 10:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 228 persistent tonals: 233.0Hz (32s), 131.8Hz (46s), 130.1Hz (453s), 197.0Hz (32s), 195.0Hz (152s)
#     Checkpoint: 195 files, 46005 windows, 2.8min elapsed, ~1min remaining
#   [196/288] session_196 — 07 Feb 11:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 713 persistent tonals: 44.2Hz (96s), 48.0Hz (79s), 55.0Hz (60s), 108.1Hz (56s), 69.6Hz (114s)
#   [197/288] session_197 — 07 Feb 12:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 828 persistent tonals: 46.2Hz (102s), 47.9Hz (57s), 53.5Hz (32s), 95.4Hz (44s), 45.0Hz (50s)
#   [198/288] session_198 — 07 Feb 13:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 569 persistent tonals: 50.8Hz (85s), 32.9Hz (126s), 36.4Hz (77s), 66.1Hz (61s), 60.8Hz (44s)
#   [199/288] session_199 — 07 Feb 14:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 429 persistent tonals: 37.4Hz (57s), 35.2Hz (95s), 41.6Hz (83s), 37.8Hz (241s), 60.2Hz (86s)
#   [200/288] session_200 — 07 Feb 15:02 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 159 persistent tonals: 48.8Hz (504s), 64.8Hz (63s), 36.0Hz (320s), 18.6Hz (116s), 33.0Hz (52s)
#     Checkpoint: 200 files, 47195 windows, 2.9min elapsed, ~1min remaining
#   [201/288] session_201 — 07 Feb 16:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 787 persistent tonals: 53.6Hz (75s), 45.9Hz (61s), 32.8Hz (102s), 44.4Hz (175s), 79.5Hz (694s)
#   [202/288] session_202 — 07 Feb 17:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 134 persistent tonals: 84.0Hz (143s), 84.0Hz (135s), 80.8Hz (190s), 83.4Hz (36s), 80.8Hz (80s)
#   [203/288] session_203 — 07 Feb 18:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 286 persistent tonals: 22.5Hz (104s), 45.1Hz (383s), 67.8Hz (328s), 22.5Hz (471s), 78.8Hz (290s)
#   [204/288] session_204 — 07 Feb 19:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 400 persistent tonals: 23.1Hz (858s), 92.6Hz (205s), 23.5Hz (710s), 35.6Hz (237s), 71.0Hz (582s)
#   [205/288] session_205 — 07 Feb 20:02 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 554 persistent tonals: 14.5Hz (89s), 12.5Hz (83s), 16.6Hz (86s), 27.9Hz (333s), 7.4Hz (31s)
#     Checkpoint: 205 files, 48385 windows, 3.0min elapsed, ~1min remaining
#   [206/288] session_206 — 07 Feb 21:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 207 persistent tonals: 5.6Hz (363s), 4.8Hz (404s), 44.4Hz (51s), 13.0Hz (286s), 65.5Hz (118s)
#   [207/288] session_207 — 07 Feb 22:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 257 persistent tonals: 8.8Hz (58s), 15.0Hz (115s), 17.2Hz (89s), 6.0Hz (114s), 62.4Hz (536s)
#   [208/288] session_208 — 07 Feb 23:02 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 184 persistent tonals: 52.2Hz (161s), 53.8Hz (77s), 52.2Hz (188s), 18.8Hz (29s), 93.5Hz (49s)
#   [209/288] session_209 — 08 Feb 00:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 67 persistent tonals: 151.5Hz (46s), 121.8Hz (64s), 154.8Hz (62s), 147.8Hz (65s), 49.4Hz (35s)
#   [210/288] session_210 — 08 Feb 01:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 71 persistent tonals: 43.4Hz (36s), 45.4Hz (184s), 85.2Hz (33s), 87.2Hz (52s), 88.4Hz (71s)
#     Checkpoint: 210 files, 49575 windows, 3.0min elapsed, ~1min remaining
#   [211/288] session_211 — 08 Feb 02:02 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 133 persistent tonals: 86.6Hz (38s), 80.8Hz (40s), 85.2Hz (60s), 99.5Hz (30s), 98.5Hz (30s)
#   [212/288] session_212 — 08 Feb 03:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 586 persistent tonals: 69.2Hz (203s), 63.1Hz (94s), 106.4Hz (213s), 65.5Hz (42s), 103.4Hz (72s)
#   [213/288] session_213 — 08 Feb 04:02 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 825 persistent tonals: 123.1Hz (587s), 112.9Hz (523s), 129.4Hz (1035s), 61.6Hz (712s), 61.6Hz (107s)
#   [214/288] session_214 — 08 Feb 05:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 76 persistent tonals: 119.8Hz (129s), 119.8Hz (130s), 119.4Hz (62s), 179.5Hz (65s), 119.8Hz (66s)
#   [215/288] session_215 — 08 Feb 06:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 165 persistent tonals: 57.6Hz (132s), 56.8Hz (417s), 113.5Hz (47s), 113.5Hz (148s), 26.8Hz (193s)
#     Checkpoint: 215 files, 50765 windows, 3.1min elapsed, ~1min remaining
#   [216/288] session_216 — 08 Feb 07:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 286 persistent tonals: 64.9Hz (34s), 58.0Hz (342s), 45.2Hz (726s), 45.5Hz (330s), 45.2Hz (188s)
#   [217/288] session_217 — 08 Feb 08:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 423 persistent tonals: 25.4Hz (31s), 28.8Hz (32s), 16.2Hz (37s), 8.8Hz (45s), 23.0Hz (38s)
#   [218/288] session_218 — 08 Feb 09:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 59 persistent tonals: 39.9Hz (92s), 15.8Hz (57s), 21.5Hz (73s), 15.2Hz (52s), 103.5Hz (48s)
#   [219/288] session_219 — 08 Feb 10:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 67 persistent tonals: 61.6Hz (57s), 104.9Hz (33s), 132.8Hz (78s), 69.9Hz (457s), 55.4Hz (29s)
#   [220/288] session_220 — 08 Feb 11:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 47 persistent tonals: 75.0Hz (250s), 78.4Hz (45s), 149.6Hz (73s), 236.6Hz (36s), 143.5Hz (118s)
#     Checkpoint: 220 files, 51955 windows, 3.2min elapsed, ~1min remaining
#   [221/288] session_221 — 08 Feb 12:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 229 persistent tonals: 52.9Hz (271s), 50.4Hz (157s), 52.9Hz (35s), 24.9Hz (150s), 57.6Hz (79s)
#   [222/288] session_222 — 08 Feb 13:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 245 persistent tonals: 52.9Hz (63s), 52.9Hz (329s), 228.6Hz (29s), 224.5Hz (29s), 227.4Hz (29s)
#   [223/288] session_223 — 08 Feb 14:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 345 persistent tonals: 19.4Hz (41s), 21.2Hz (40s), 22.6Hz (41s), 23.5Hz (41s), 46.8Hz (256s)
#   [224/288] session_224 — 08 Feb 15:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 39 persistent tonals: 46.8Hz (137s), 46.8Hz (318s), 10.2Hz (40s), 8.4Hz (47s), 15.4Hz (31s)
#   [225/288] session_225 — 08 Feb 16:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 9 persistent tonals: 46.1Hz (29s), 63.8Hz (96s), 63.8Hz (76s), 5.4Hz (30s), 42.8Hz (39s)
#     Checkpoint: 225 files, 53145 windows, 3.3min elapsed, ~1min remaining
#   [226/288] session_226 — 08 Feb 17:02 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 39 persistent tonals: 20.6Hz (42s), 19.2Hz (42s), 37.9Hz (42s), 37.0Hz (42s), 25.1Hz (38s)
#   [227/288] session_227 — 08 Feb 18:02 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 107 persistent tonals: 45.1Hz (326s), 59.2Hz (66s), 21.4Hz (63s), 78.6Hz (63s), 22.9Hz (71s)
#   [228/288] session_228 — 08 Feb 19:02 (Stages 1+2)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 303 persistent tonals: 138.4Hz (174s), 73.2Hz (257s), 48.6Hz (664s), 97.4Hz (420s), 97.5Hz (262s)
#   [229/288] session_229 — 08 Feb 20:02 (Stages 1+2)
#     512 Hz, 3596s, 1.8M samples
# ...
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 423 persistent tonals: 25.4Hz (31s), 28.8Hz (32s), 16.2Hz (37s), 8.8Hz (45s), 23.0Hz (38s)
#   [218/288] session_218 — 08 Feb 09:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 59 persistent tonals: 39.9Hz (92s), 15.8Hz (57s), 21.5Hz (73s), 15.2Hz (52s), 103.5Hz (48s)
#   [219/288] session_219 — 08 Feb 10:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 67 persistent tonals: 61.6Hz (57s), 104.9Hz (33s), 132.8Hz (78s), 69.9Hz (457s), 55.4Hz (29s)
#   [220/288] session_220 — 08 Feb 11:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 47 persistent tonals: 75.0Hz (250s), 78.4Hz (45s), 149.6Hz (73s), 236.6Hz (36s), 143.5Hz (118s)
#     Checkpoint: 220 files, 51955 windows, 23.6min elapsed, ~7min remaining
#   [221/288] session_221 — 08 Feb 12:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 229 persistent tonals: 52.9Hz (271s), 50.4Hz (157s), 52.9Hz (35s), 24.9Hz (150s), 57.6Hz (79s)
#   [222/288] session_222 — 08 Feb 13:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 245 persistent tonals, DEMON on 4 windows: 52.9Hz (63s), 52.9Hz (329s), 228.6Hz (29s), 224.5Hz (29s), 227.4Hz (29s)
#   [223/288] session_223 — 08 Feb 14:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 345 persistent tonals, DEMON on 2 windows: 19.4Hz (41s), 21.2Hz (40s), 22.6Hz (41s), 23.5Hz (41s), 46.8Hz (256s)
#   [224/288] session_224 — 08 Feb 15:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 39 persistent tonals, DEMON on 2 windows: 46.8Hz (137s), 46.8Hz (318s), 10.2Hz (40s), 8.4Hz (47s), 15.4Hz (31s)
#   [225/288] session_225 — 08 Feb 16:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 9 persistent tonals: 46.1Hz (29s), 63.8Hz (96s), 63.8Hz (76s), 5.4Hz (30s), 42.8Hz (39s)
#     Checkpoint: 225 files, 53145 windows, 24.1min elapsed, ~7min remaining
#   [226/288] session_226 — 08 Feb 17:02 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 39 persistent tonals, DEMON on 1 windows: 20.6Hz (42s), 19.2Hz (42s), 37.9Hz (42s), 37.0Hz (42s), 25.1Hz (38s)
#   [227/288] session_227 — 08 Feb 18:02 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 107 persistent tonals: 45.1Hz (326s), 59.2Hz (66s), 21.4Hz (63s), 78.6Hz (63s), 22.9Hz (71s)
#   [228/288] session_228 — 08 Feb 19:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 303 persistent tonals, DEMON on 2 windows: 138.4Hz (174s), 73.2Hz (257s), 48.6Hz (664s), 97.4Hz (420s), 97.5Hz (262s)
#   [229/288] session_229 — 08 Feb 20:02 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 71 persistent tonals: 126.2Hz (47s), 126.2Hz (36s), 126.2Hz (64s), 113.1Hz (84s), 126.2Hz (69s)
#   [230/288] session_230 — 08 Feb 21:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 22 persistent tonals, DEMON on 2 windows: 94.8Hz (36s), 47.4Hz (72s), 4.2Hz (41s), 94.8Hz (31s), 5.5Hz (30s)
#     Checkpoint: 230 files, 54335 windows, 24.7min elapsed, ~6min remaining
#   [231/288] session_231 — 08 Feb 22:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 50 persistent tonals: 14.1Hz (50s), 19.1Hz (48s), 29.4Hz (42s), 9.4Hz (47s), 9.9Hz (49s)
#   [232/288] session_232 — 08 Feb 23:02 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 107 persistent tonals: 46.4Hz (30s), 84.8Hz (106s), 44.8Hz (207s), 117.8Hz (30s), 52.6Hz (37s)
#   [233/288] session_233 — 09 Feb 00:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 138 persistent tonals: 48.9Hz (135s), 134.5Hz (43s), 54.0Hz (34s), 73.6Hz (135s), 73.4Hz (73s)
#   [234/288] session_234 — 09 Feb 01:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 141 persistent tonals: 57.9Hz (63s), 47.5Hz (166s), 56.1Hz (85s), 56.1Hz (73s), 47.5Hz (116s)
#   [235/288] session_235 — 09 Feb 02:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 171 persistent tonals: 35.4Hz (115s), 37.9Hz (31s), 57.5Hz (54s), 36.5Hz (144s), 36.5Hz (123s)
#     Checkpoint: 235 files, 55525 windows, 25.2min elapsed, ~6min remaining
#   [236/288] session_236 — 09 Feb 03:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 400 persistent tonals, DEMON on 6 windows: 56.9Hz (712s), 61.2Hz (309s), 122.5Hz (787s), 23.6Hz (30s), 240.6Hz (29s)
#   [237/288] session_237 — 09 Feb 04:02 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 584 persistent tonals, DEMON on 44 windows: 127.8Hz (1018s), 127.2Hz (647s), 122.1Hz (889s), 141.0Hz (946s), 112.5Hz (904s)
#   [238/288] session_238 — 09 Feb 05:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 1007 persistent tonals, DEMON on 30 windows: 127.0Hz (148s), 138.6Hz (459s), 22.5Hz (496s), 161.4Hz (197s), 172.9Hz (498s)
#   [239/288] session_239 — 09 Feb 06:02 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 724 persistent tonals: 55.1Hz (793s), 60.4Hz (782s), 46.8Hz (179s), 52.0Hz (216s), 57.5Hz (1157s)
#   [240/288] session_240 — 09 Feb 07:02 (Stages 1+2+3)
#     512 Hz, 2698s, 1.4M samples
#     178 windows, 368 persistent tonals, DEMON on 2 windows: 110.1Hz (179s), 110.1Hz (545s), 112.8Hz (188s), 70.6Hz (56s), 122.2Hz (32s)
#     Checkpoint: 240 files, 56655 windows, 25.8min elapsed, ~5min remaining
#   [241/288] session_241 — 09 Feb 07:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 721 persistent tonals, DEMON on 8 windows: 94.0Hz (32s), 95.6Hz (34s), 95.6Hz (46s), 205.5Hz (201s), 204.9Hz (194s)
#   [242/288] session_242 — 09 Feb 08:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 157 persistent tonals: 150.6Hz (34s), 148.2Hz (82s), 133.8Hz (50s), 136.1Hz (65s), 150.6Hz (39s)
#   [243/288] session_243 — 09 Feb 09:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 40 persistent tonals: 66.4Hz (467s), 100.5Hz (40s), 99.1Hz (40s), 61.4Hz (303s), 96.6Hz (33s)
#   [244/288] session_244 — 09 Feb 10:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 103 persistent tonals, DEMON on 3 windows: 74.4Hz (80s), 67.4Hz (30s), 74.4Hz (79s), 22.9Hz (64s), 74.4Hz (58s)
#   [245/288] session_245 — 09 Feb 11:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 348 persistent tonals: 132.9Hz (186s), 132.9Hz (117s), 5.2Hz (29s), 198.9Hz (91s), 132.9Hz (254s)
#     Checkpoint: 245 files, 57845 windows, 26.3min elapsed, ~5min remaining
#   [246/288] session_246 — 09 Feb 12:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 221 persistent tonals: 34.2Hz (72s), 35.6Hz (71s), 19.8Hz (83s), 22.9Hz (78s), 32.8Hz (77s)
#   [247/288] session_247 — 09 Feb 13:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 144 persistent tonals: 131.1Hz (169s), 129.4Hz (75s), 39.9Hz (52s), 39.4Hz (50s), 131.5Hz (29s)
#   [248/288] session_248 — 09 Feb 14:50 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 13 persistent tonals, DEMON on 2 windows: 131.0Hz (45s), 30.6Hz (49s), 30.6Hz (38s), 30.6Hz (38s), 131.0Hz (41s)
#   [249/288] session_249 — 09 Feb 15:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 23 persistent tonals, DEMON on 4 windows: 18.9Hz (72s), 18.9Hz (30s), 18.9Hz (56s), 67.2Hz (37s), 30.6Hz (36s)
#   [250/288] session_250 — 09 Feb 16:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 42 persistent tonals, DEMON on 2 windows: 23.2Hz (31s), 86.4Hz (44s), 15.2Hz (40s), 15.2Hz (35s), 17.9Hz (41s)
#     Checkpoint: 250 files, 59035 windows, 26.9min elapsed, ~4min remaining
#   [251/288] session_251 — 09 Feb 17:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 613 persistent tonals, DEMON on 11 windows: 158.0Hz (839s), 85.9Hz (177s), 40.0Hz (534s), 59.2Hz (757s), 59.9Hz (842s)
#   [252/288] session_252 — 09 Feb 18:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 173 persistent tonals: 157.5Hz (36s), 207.1Hz (72s), 236.8Hz (55s), 138.0Hz (145s), 61.0Hz (34s)
#   [253/288] session_253 — 09 Feb 19:50 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 419 persistent tonals: 136.6Hz (568s), 125.0Hz (288s), 65.5Hz (453s), 135.4Hz (391s), 33.6Hz (183s)
#   [254/288] session_254 — 09 Feb 20:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 398 persistent tonals, DEMON on 25 windows: 62.9Hz (974s), 135.4Hz (981s), 67.9Hz (1046s), 56.1Hz (683s), 135.6Hz (1017s)
#   [255/288] session_255 — 09 Feb 21:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 386 persistent tonals: 65.8Hz (370s), 131.4Hz (62s), 65.8Hz (71s), 125.6Hz (271s), 131.4Hz (77s)
#     Checkpoint: 255 files, 60225 windows, 27.4min elapsed, ~4min remaining
#   [256/288] session_256 — 09 Feb 22:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 653 persistent tonals: 167.2Hz (288s), 167.2Hz (95s), 125.6Hz (134s), 125.6Hz (469s), 167.2Hz (194s)
#   [257/288] session_257 — 09 Feb 23:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 1 persistent tonals: 28.5Hz (29s)
#   [258/288] session_258 — 10 Feb 00:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 76 persistent tonals: 49.4Hz (34s), 54.0Hz (670s), 49.4Hz (102s), 99.4Hz (84s), 99.5Hz (115s)
#   [259/288] session_259 — 10 Feb 01:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 853 persistent tonals: 64.2Hz (943s), 128.5Hz (675s), 220.8Hz (124s), 117.9Hz (562s), 84.8Hz (366s)
#   [260/288] session_260 — 10 Feb 02:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 319 persistent tonals: 64.4Hz (589s), 128.2Hz (201s), 84.8Hz (152s), 67.8Hz (307s), 81.9Hz (157s)
#     Checkpoint: 260 files, 61415 windows, 28.0min elapsed, ~3min remaining
#   [261/288] session_261 — 10 Feb 03:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 24 persistent tonals: 84.2Hz (29s), 9.0Hz (74s), 82.2Hz (33s), 82.2Hz (35s), 6.8Hz (81s)
#   [262/288] session_262 — 10 Feb 04:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 4 persistent tonals: 24.6Hz (33s), 161.0Hz (43s), 58.0Hz (38s), 61.4Hz (29s)
#   [263/288] session_263 — 10 Feb 05:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 12 persistent tonals, DEMON on 2 windows: 70.8Hz (199s), 60.8Hz (57s), 81.2Hz (42s), 65.5Hz (50s), 135.5Hz (33s)
#   [264/288] session_264 — 10 Feb 06:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 463 persistent tonals: 169.8Hz (163s), 146.0Hz (299s), 121.5Hz (153s), 146.0Hz (118s), 121.5Hz (109s)
#   [265/288] session_265 — 10 Feb 07:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 81 persistent tonals: 18.1Hz (97s), 230.4Hz (132s), 4.8Hz (124s), 15.4Hz (72s), 235.9Hz (36s)
#     Checkpoint: 265 files, 62605 windows, 28.6min elapsed, ~2min remaining
#   [266/288] session_266 — 10 Feb 08:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 28 persistent tonals: 25.6Hz (29s), 206.8Hz (63s), 210.9Hz (47s), 61.8Hz (33s), 213.4Hz (43s)
#   [267/288] session_267 — 10 Feb 09:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 32 persistent tonals: 85.6Hz (63s), 87.6Hz (60s), 66.4Hz (487s), 71.9Hz (534s), 85.0Hz (71s)
#   [268/288] session_268 — 10 Feb 10:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 88 persistent tonals: 21.4Hz (35s), 14.6Hz (85s), 10.9Hz (96s), 21.9Hz (31s), 42.2Hz (31s)
#   [269/288] session_269 — 10 Feb 11:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 405 persistent tonals, DEMON on 2 windows: 121.8Hz (289s), 208.4Hz (93s), 205.6Hz (94s), 193.6Hz (157s), 196.5Hz (167s)
#   [270/288] session_270 — 10 Feb 12:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 108 persistent tonals, DEMON on 4 windows: 32.4Hz (88s), 19.5Hz (122s), 26.2Hz (89s), 15.1Hz (119s), 17.4Hz (125s)
#     Checkpoint: 270 files, 63795 windows, 29.1min elapsed, ~2min remaining
#   [271/288] session_271 — 10 Feb 13:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 37 persistent tonals: 31.2Hz (37s), 18.9Hz (56s), 36.6Hz (50s), 21.8Hz (374s), 8.6Hz (66s)
#   [272/288] session_272 — 10 Feb 14:50 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 4 persistent tonals: 4.0Hz (34s), 27.6Hz (35s), 27.6Hz (65s), 27.6Hz (37s)
#   [273/288] session_273 — 10 Feb 15:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 125 persistent tonals, DEMON on 2 windows: 72.2Hz (195s), 205.4Hz (58s), 69.9Hz (163s), 75.4Hz (152s), 169.6Hz (73s)
#   [274/288] session_274 — 10 Feb 16:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 915 persistent tonals, DEMON on 27 windows: 103.9Hz (368s), 22.5Hz (576s), 138.6Hz (516s), 107.0Hz (328s), 174.2Hz (104s)
#   [275/288] session_275 — 10 Feb 17:50 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 627 persistent tonals, DEMON on 2 windows: 44.2Hz (916s), 177.8Hz (377s), 155.1Hz (530s), 66.5Hz (400s), 77.2Hz (507s)
#     Checkpoint: 275 files, 64985 windows, 29.7min elapsed, ~1min remaining
#   [276/288] session_276 — 10 Feb 18:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 572 persistent tonals: 66.5Hz (353s), 72.6Hz (278s), 79.1Hz (342s), 90.0Hz (110s), 80.9Hz (353s)
#   [277/288] session_277 — 10 Feb 19:50 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 107 persistent tonals: 36.2Hz (77s), 36.2Hz (530s), 34.6Hz (306s), 30.5Hz (43s), 28.1Hz (34s)
#   [278/288] session_278 — 10 Feb 20:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 81 persistent tonals: 121.0Hz (77s), 60.2Hz (54s), 60.2Hz (151s), 119.1Hz (31s), 121.0Hz (248s)
#   [279/288] session_279 — 10 Feb 21:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 166 persistent tonals: 232.9Hz (37s), 234.9Hz (48s), 230.1Hz (56s), 36.4Hz (40s), 230.1Hz (78s)
#   [280/288] session_280 — 10 Feb 22:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 20 persistent tonals: 201.9Hz (86s), 36.2Hz (44s), 201.9Hz (84s), 201.2Hz (51s), 201.9Hz (103s)
#     Checkpoint: 280 files, 66175 windows, 30.2min elapsed, ~1min remaining
#   [281/288] session_281 — 10 Feb 23:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 65 persistent tonals: 105.8Hz (95s), 74.5Hz (166s), 212.8Hz (85s), 89.8Hz (99s), 212.8Hz (57s)
#   [282/288] session_282 — 11 Feb 00:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 163 persistent tonals: 14.1Hz (67s), 64.4Hz (35s), 17.1Hz (53s), 9.5Hz (203s), 7.9Hz (208s)
#   [283/288] session_283 — 11 Feb 01:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 357 persistent tonals: 113.9Hz (75s), 51.6Hz (148s), 77.2Hz (29s), 115.6Hz (70s), 141.6Hz (51s)
#   [284/288] session_284 — 11 Feb 02:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 187 persistent tonals: 59.6Hz (107s), 70.4Hz (174s), 36.1Hz (44s), 97.1Hz (236s), 34.8Hz (29s)
#   [285/288] session_285 — 11 Feb 03:50 (Stages 1+2+3)
#     512 Hz, 3596s, 1.8M samples
#     238 windows, 38 persistent tonals: 124.4Hz (93s), 151.1Hz (50s), 148.9Hz (37s), 61.8Hz (30s), 124.4Hz (42s)
#     Checkpoint: 285 files, 67365 windows, 30.8min elapsed, ~0min remaining
#   [286/288] session_286 — 11 Feb 04:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 128 persistent tonals: 33.8Hz (328s), 73.9Hz (434s), 76.5Hz (354s), 73.9Hz (35s), 73.2Hz (190s)
#   [287/288] session_287 — 11 Feb 05:50 (Stages 1+2+3)
#     512 Hz, 3595s, 1.8M samples
#     238 windows, 175 persistent tonals: 113.4Hz (356s), 140.4Hz (196s), 144.1Hz (409s), 113.5Hz (266s), 138.9Hz (104s)
#   [288/288] session_288 — 11 Feb 06:50 (Stages 1+2+3)
#     512 Hz, 709s, 0.4M samples
#     46 windows, 56 persistent tonals: 122.1Hz (88s), 124.9Hz (89s), 121.2Hz (94s), 131.0Hz (37s), 119.1Hz (36s)
#     Checkpoint: 288 files, 67887 windows, 31.0min elapsed, ~0min remaining
#
# Pass 2 complete: 31.0 min
#
# ============================================================
# PROCESSING COMPLETE
#   Files: 288
#   Windows: 67887
#   Total time: 35.3 minutes
#   Output: /content/drive/MyDrive/SKANN_SSL/lofar_results_all_sessions/

# %% [markdown]
# ## 7. Analysis & Event Detection
#
# Reads the per-window CSV and finds vessel transit events using RMS energy
# combined with tonal detection. Also summarises DEMON results.

# %%
# Load results
csv_path = os.path.join(OUTPUT_DIR, 'lofar_hydrophone_results.csv')
df = pd.read_csv(csv_path)
df['ts'] = pd.to_datetime(df['timestamp'])
df = df.sort_values('ts').reset_index(drop=True)

print(f'Loaded {len(df)} windows')
print(f'Date range: {df["ts"].min()} → {df["ts"].max()}')

# ---- Summary statistics ----
rms_mean = df['rms_energy'].mean()
rms_std = df['rms_energy'].std()
rms_thresh = rms_mean + RMS_SIGMA_THRESHOLD * rms_std

print(f'\n--- STAGE 1: RMS ENERGY ---')
print(f'  Range: {df["rms_energy"].min():.6f} – {df["rms_energy"].max():.6f}')
print(f'  Dynamic range: {df["rms_energy"].max()/df["rms_energy"].min():.0f}×')
print(f'  Mean: {rms_mean:.6f}, Std: {rms_std:.6f}')
print(f'  Detection threshold ({RMS_SIGMA_THRESHOLD}σ): {rms_thresh:.6f}')
for sigma in [1.0, 1.5, 2.0, 3.0]:
    t = rms_mean + sigma * rms_std
    n = (df['rms_energy'] > t).sum()
    print(f'    >{sigma}σ: {n} windows ({100*n/len(df):.1f}%)')

print(f'\n--- STAGE 2: TONAL DETECTION ---')
print(f'  Windows with ≥1 tonal: {(df["n_tonals"] > 0).sum()} ({100*(df["n_tonals"] > 0).sum()/len(df):.1f}%)')
print(f'  Windows with ≥3 tonals: {(df["n_tonals"] >= 3).sum()} ({100*(df["n_tonals"] >= 3).sum()/len(df):.1f}%)')
print(f'  Max tonals in one window: {df["n_tonals"].max()}')
print(f'  Mean tonal energy: {df["tonal_energy"].mean():.2f}')
print(f'  Max tonal energy: {df["tonal_energy"].max():.2f}')

print(f'\n--- STAGE 3: DEMON (conditional) ---')
demon_attempted = df['demon_confidence'] != 'NONE'
demon_high = df['demon_confidence'] == 'HIGH'
demon_low = df['demon_confidence'] == 'LOW'
print(f'  DEMON attempted: {demon_attempted.sum()} windows ({100*demon_attempted.sum()/len(df):.1f}%)')
print(f'  HIGH confidence: {demon_high.sum()} windows')
print(f'  LOW confidence:  {demon_low.sum()} windows')
print(f'  Not attempted:   {(~demon_attempted).sum()} windows')
if demon_attempted.any():
    demon_df = df[demon_attempted]
    print(f'  Blade rate range: {demon_df["blade_rate_hz"].min():.1f} – {demon_df["blade_rate_hz"].max():.1f} Hz')
    print(f'  Shaft rate range: {demon_df["shaft_rate_hz"].min():.2f} – {demon_df["shaft_rate_hz"].max():.2f} Hz')
    if demon_high.any():
        high_df = df[demon_high]
        print(f'  HIGH-confidence blade rates: {high_df["blade_rate_hz"].median():.1f} Hz (median)')

# ---- Soft-gated vessel score ----
rms_ratio = df['rms_energy'] / rms_mean
gate_weight = np.clip(rms_ratio / 2.0, 0.0, 1.0)
gated_n_tonals = df['n_tonals'] * gate_weight
gated_tonal_energy = df['tonal_energy'] * gate_weight

df['vessel_score'] = (
    np.log10(1 + rms_ratio) *
    (1 + gated_n_tonals) *
    (1 + np.log10(1 + gated_tonal_energy))
)

save_cols = [c for c in df.columns if c not in ('ts',)]
df[save_cols].to_csv(csv_path, index=False)
print(f'\nUpdated CSV saved with soft-gated vessel_score')

print(f'\n--- VESSEL SCORE ---')
print(f'  Range: {df["vessel_score"].min():.2f} – {df["vessel_score"].max():.2f}')

day = df[(df['ts'].dt.hour >= 6) & (df['ts'].dt.hour < 18)]
night = df[(df['ts'].dt.hour >= 18) | (df['ts'].dt.hour < 6)]
print(f'\n--- DAY / NIGHT ---')
print(f'  Day mean RMS:     {day["rms_energy"].mean():.6f}')
print(f'  Night mean RMS:   {night["rms_energy"].mean():.6f}')
if night['rms_energy'].mean() > 0:
    print(f'  RMS ratio:        {day["rms_energy"].mean()/night["rms_energy"].mean():.2f}×')

# ---- Event detection ----
df['elevated'] = df['rms_energy'] > rms_thresh
elevated_idx = set(df[df['elevated']].index)
expanded = set()
for idx in elevated_idx:
    for offset in range(-EVENT_MERGE_RADIUS, EVENT_MERGE_RADIUS + 1):
        if 0 <= idx + offset < len(df):
            expanded.add(idx + offset)

df['in_event'] = df.index.isin(expanded)
df['event_group'] = (df['in_event'] != df['in_event'].shift()).cumsum()

events = []
for gid, group in df[df['in_event']].groupby('event_group'):
    if len(group) < EVENT_MIN_WINDOWS:
        continue
    start = group['ts'].iloc[0]
    end = group['ts'].iloc[-1]
    dur_min = (end - start).total_seconds() / 60
    peak_rms = group['rms_energy'].max()

    # DEMON summary for this event
    demon_windows = group[group['demon_confidence'] != 'NONE']
    if len(demon_windows) > 0:
        ev_blade_rate = demon_windows['blade_rate_hz'].median()
        ev_shaft_rate = demon_windows['shaft_rate_hz'].median()
        ev_n_blades = int(demon_windows['est_n_blades'].mode().iloc[0]) if len(demon_windows) > 0 else None
        ev_rpm = demon_windows['est_rpm'].median()
        ev_demon_conf = 'HIGH' if (demon_windows['demon_confidence'] == 'HIGH').any() else 'LOW'
    else:
        ev_blade_rate = None
        ev_shaft_rate = None
        ev_n_blades = None
        ev_rpm = None
        ev_demon_conf = 'NONE'

    events.append({
        'event_id': len(events) + 1,
        'start': start, 'end': end, 'dur_min': dur_min,
        'n_windows': len(group),
        'peak_rms': peak_rms,
        'mean_rms': group['rms_energy'].mean(),
        'rms_ratio': peak_rms / rms_mean,
        'mean_tonals': group['n_tonals'].mean(),
        'max_tonals': group['n_tonals'].max(),
        'mean_tonal_energy': group['tonal_energy'].mean(),
        'mean_vessel_score': group['vessel_score'].mean(),
        'max_vessel_score': group['vessel_score'].max(),
        'strongest_tonal_hz': group.loc[group['strongest_tonal_db'].idxmax(), 'strongest_tonal_hz'] if group['strongest_tonal_db'].max() > 0 else 0,
        'blade_rate_hz': ev_blade_rate,
        'shaft_rate_hz': ev_shaft_rate,
        'est_n_blades': ev_n_blades,
        'est_rpm': ev_rpm,
        'demon_confidence': ev_demon_conf,
        'files': sorted(group['file'].unique().tolist()),
    })

# Classify events
significant = []
for ev in events:
    is_sig = ev['dur_min'] >= SIGNIFICANT_DURATION_MIN or ev['rms_ratio'] >= SIGNIFICANT_RMS_FACTOR
    has_tonals = ev['mean_vessel_score'] >= 2.0
    if is_sig:
        if has_tonals and ev['dur_min'] >= 8:
            ev['assessment'] = 'CONFIRMED VESSEL'
        elif has_tonals:
            ev['assessment'] = 'PROBABLE VESSEL'
        elif ev['rms_ratio'] >= 10:
            ev['assessment'] = 'HIGH ENERGY (no tonals)'
        else:
            ev['assessment'] = 'ELEVATED ACTIVITY'
        significant.append(ev)
    else:
        ev['assessment'] = 'brief transient'

print(f'\n{"="*60}')
print(f'EVENT DETECTION RESULTS')
print(f'{"="*60}')
print(f'  Total events: {len(events)}')
print(f'  Significant: {len(significant)}')
print(f'\n{"#":>3} {"Time":<26} {"Dur":>5} {"Peak":>7} {"Tonals":>7} {"Score":>6} {"BR":>6} {"SR":>6} {"Conf":>5} {"Assessment"}')
print("-"*105)
for ev in sorted(significant, key=lambda e: e['rms_ratio'], reverse=True):
    br_str = f'{ev["blade_rate_hz"]:.1f}' if ev['blade_rate_hz'] else '  —'
    sr_str = f'{ev["shaft_rate_hz"]:.2f}' if ev['shaft_rate_hz'] else '  —'
    conf_str = ev['demon_confidence'][:3] if ev['demon_confidence'] != 'NONE' else ' —'
    print(f'{ev["event_id"]:3d} {ev["start"].strftime("%d %b %H:%M")}–{ev["end"].strftime("%H:%M")}'
          f'  {ev["dur_min"]:4.0f}m {ev["rms_ratio"]:6.1f}× '
          f'{ev["mean_tonals"]:6.1f} {ev["max_vessel_score"]:5.1f} '
          f'{br_str:>6} {sr_str:>6} {conf_str:>5}  '
          f'{ev["assessment"]}')

# Save events CSV
events_df = pd.DataFrame([{
    'event_id': e['event_id'],
    'start': e['start'].isoformat(),
    'end': e['end'].isoformat(),
    'dur_min': round(e['dur_min'], 1),
    'n_windows': e['n_windows'],
    'peak_rms': round(e['peak_rms'], 6),
    'rms_ratio': round(e['rms_ratio'], 1),
    'mean_tonals': round(e['mean_tonals'], 2),
    'max_tonals': e['max_tonals'],
    'mean_tonal_energy': round(e['mean_tonal_energy'], 2),
    'mean_vessel_score': round(e['mean_vessel_score'], 2),
    'max_vessel_score': round(e['max_vessel_score'], 2),
    'strongest_tonal_hz': round(e['strongest_tonal_hz'], 2),
    'blade_rate_hz': round(e['blade_rate_hz'], 2) if e['blade_rate_hz'] else None,
    'shaft_rate_hz': round(e['shaft_rate_hz'], 3) if e['shaft_rate_hz'] else None,
    'est_n_blades': e['est_n_blades'],
    'est_rpm': round(e['est_rpm'], 1) if e['est_rpm'] else None,
    'demon_confidence': e['demon_confidence'],
    'assessment': e['assessment'],
} for e in events])
events_path = os.path.join(OUTPUT_DIR, 'transit_events.csv')
events_df.to_csv(events_path, index=False)
print(f'\nEvents saved to: {events_path}')
# Out:
# Loaded 67887 windows
# Date range: 2026-01-30 09:04:07 → 2026-02-11 07:01:51
#
# --- STAGE 1: RMS ENERGY ---
#   Range: 0.000071 – 0.031198
#   Dynamic range: 439×
#   Mean: 0.000327, Std: 0.000593
#   Detection threshold (1.0σ): 0.000920
#     >1.0σ: 2774 windows (4.1%)
#     >1.5σ: 1526 windows (2.2%)
#     >2.0σ: 1000 windows (1.5%)
#     >3.0σ: 547 windows (0.8%)
#
# --- STAGE 2: TONAL DETECTION ---
#   Windows with ≥1 tonal: 38152 (56.2%)
#   Windows with ≥3 tonals: 23842 (35.1%)
#   Max tonals in one window: 117
#   Mean tonal energy: 92.45
#   Max tonal energy: 3567.06
#
# --- STAGE 3: DEMON (conditional) ---
#   DEMON attempted: 2326 windows (3.4%)
#   HIGH confidence: 609 windows
#   LOW confidence:  1717 windows
#   Not attempted:   65561 windows
#   Blade rate range: 2.0 – 49.9 Hz
#   Shaft rate range: 0.50 – 16.41 Hz
#   HIGH-confidence blade rates: 6.7 Hz (median)
#
# Updated CSV saved with soft-gated vessel_score
#
# --- VESSEL SCORE ---
#   Range: 0.09 – 933.80
#
# --- DAY / NIGHT ---
#   Day mean RMS:     0.000375
#   Night mean RMS:   0.000279
#   RMS ratio:        1.34×
#
# ============================================================
# EVENT DETECTION RESULTS
# ============================================================
#   Total events: 250
#   Significant: 148
#
#   # Time                         Dur    Peak  Tonals  Score     BR     SR  Conf Assessment
# ---------------------------------------------------------------------------------------------------------
#  76 03 Feb 05:25–05:47    22m   95.5×   88.1 933.8   11.8   3.18   HIG  CONFIRMED VESSEL
# 107 03 Feb 20:38–20:42     4m   87.6×   70.5 713.4   14.9   2.98   LOW  PROBABLE VESSEL
#  64 02 Feb 08:03–08:07     4m   76.4×    6.5 531.5   19.0   3.80   LOW  PROBABLE VESSEL
# 177 06 Feb 12:55–13:00     4m   76.0×   11.0 503.2   16.2   3.24   HIG  PROBABLE VESSEL
# 228 09 Feb 05:11–05:33    22m   57.8×   23.6 335.0    5.8   1.45   LOW  CONFIRMED VESSEL
# 142 05 Feb 11:45–11:51     6m   57.4×    9.2 360.3    7.1   1.49   HIG  PROBABLE VESSEL
# 154 05 Feb 15:17–16:28    71m   51.1×   19.9 542.4    5.9   1.34   HIG  CONFIRMED VESSEL
# 232 09 Feb 10:48–10:52     4m   45.5×    1.6  84.9      —      —     —  PROBABLE VESSEL
# 158 05 Feb 17:05–17:34    29m   45.3×   13.8 236.9    4.7   0.95   HIG  CONFIRMED VESSEL
# 134 05 Feb 08:10–08:36    25m   44.5×   60.9 820.5    6.5   1.63   HIG  CONFIRMED VESSEL
#  94 03 Feb 13:46–14:05    19m   43.6×   10.1 296.1   15.5   3.11   HIG  CONFIRMED VESSEL
# 243 10 Feb 11:49–11:54     5m   42.1×    4.0 231.2   12.0   2.40   HIG  PROBABLE VESSEL
# 155 05 Feb 16:31–16:44    13m   39.0×    3.1 128.2    3.9   1.26   HIG  CONFIRMED VESSEL
#  95 03 Feb 14:09–14:13     4m   34.7×   12.2 275.0    4.5   1.12   HIG  PROBABLE VESSEL
# 160 05 Feb 19:59–20:09    10m   34.1×   88.2 738.5   23.1   5.77   HIG  CONFIRMED VESSEL
# 143 05 Feb 11:54–11:58     4m   34.0×    8.6 449.4      —      —     —  PROBABLE VESSEL
#  96 03 Feb 14:15–14:19     4m   27.1×    4.6  84.7    7.7   1.55   HIG  PROBABLE VESSEL
# 132 05 Feb 04:33–04:39     6m   26.6×   46.9 537.1    3.0   0.83   HIG  PROBABLE VESSEL
#  59 01 Feb 16:04–16:09     4m   25.7×    0.5  36.5      —      —     —  PROBABLE VESSEL
#  36 31 Jan 14:09–14:13     4m   24.4×    0.3  26.7    9.4   1.88   HIG  HIGH ENERGY (no tonals)
#  93 03 Feb 13:36–13:44     8m   24.0×    7.9 141.3    2.4   0.81   HIG  CONFIRMED VESSEL
#  56 01 Feb 07:59–08:07     8m   23.9×   84.8 680.1   23.5   5.91   HIG  CONFIRMED VESSEL
# 121 04 Feb 14:12–14:16     4m   23.7×    4.4 102.6      —      —     —  PROBABLE VESSEL
# 131 05 Feb 00:18–00:22     4m   22.1×   14.9 243.2      —      —     —  PROBABLE VESSEL
# 206 07 Feb 18:00–19:26    86m   22.1×    9.7 535.1   22.5   4.98   HIG  CONFIRMED VESSEL
# 115 04 Feb 08:52–09:07    15m   20.0×   31.2 414.2   10.3   3.00   HIG  CONFIRMED VESSEL
#  43 31 Jan 15:46–16:10    24m   19.3×   26.9 546.5   27.6   8.45   HIG  CONFIRMED VESSEL
# 145 05 Feb 12:11–12:15     4m   18.5×    1.5  57.7   12.0   2.41   HIG  PROBABLE VESSEL
# 149 05 Feb 12:55–13:07    12m   17.6×    3.2 135.6    6.1   1.52   HIG  CONFIRMED VESSEL
# 141 05 Feb 11:31–11:38     6m   17.6×    5.2 208.2    2.6   0.66   HIG  PROBABLE VESSEL
# 138 05 Feb 10:59–11:07     8m   17.2×    1.4  54.1   10.4   2.09   HIG  CONFIRMED VESSEL
# 130 04 Feb 23:46–23:50     4m   15.5×    4.4 119.8   13.9   2.92   HIG  PROBABLE VESSEL
#  19 31 Jan 00:57–01:02     5m   15.2×   50.9 481.9    2.7   0.80   HIG  PROBABLE VESSEL
#  98 03 Feb 14:42–14:51     9m   15.1×   10.7 150.9    6.0   1.21   HIG  CONFIRMED VESSEL
#  47 31 Jan 18:41–18:45     4m   14.3×    0.8   8.0      —      —     —  HIGH ENERGY (no tonals)
#  25 31 Jan 08:39–08:53    14m   13.9×   16.4 408.5    2.9   0.69   HIG  CONFIRMED VESSEL
#  97 03 Feb 14:20–14:27     6m   13.5×    3.8  98.5    2.7   0.79   LOW  PROBABLE VESSEL
#  14 30 Jan 17:09–17:13     4m   13.3×    0.5  25.7      —      —     —  PROBABLE VESSEL
# 186 06 Feb 18:17–18:30    13m   13.1×   69.7 543.9    9.7   2.46   HIG  CONFIRMED VESSEL
#  99 03 Feb 15:08–15:16     9m   12.9×   63.4 405.7   43.5  10.88   LOW  CONFIRMED VESSEL
#  61 02 Feb 04:15–04:22     7m   12.8×   37.0 391.2    3.0   0.61   HIG  PROBABLE VESSEL
#  45 31 Jan 16:28–16:32     4m   12.8×    0.5  11.2      —      —     —  HIGH ENERGY (no tonals)
#  84 03 Feb 10:25–11:22    57m   12.7×   38.4 410.4   20.7   5.17   HIG  CONFIRMED VESSEL
# 163 06 Feb 03:00–03:24    24m   12.6×   41.9 337.0    6.4   1.60   HIG  CONFIRMED VESSEL
# 241 10 Feb 07:32–07:36     4m   12.6×    7.1  62.3      —      —     —  PROBABLE VESSEL
# 217 08 Feb 14:51–14:55     4m   12.3×    4.0  60.6   41.9   8.38   LOW  PROBABLE VESSEL
# 223 08 Feb 21:33–21:37     4m   12.2×    8.0 317.1    3.0   0.75   HIG  PROBABLE VESSEL
# 233 09 Feb 11:05–11:09     4m   12.1×   10.2 174.9    8.3   1.65   HIG  PROBABLE VESSEL
# 114 04 Feb 08:31–08:46    15m   12.0×   72.4 451.4   20.2   5.05   HIG  CONFIRMED VESSEL
# 179 06 Feb 14:42–15:03    20m   11.3×   30.1 462.6    9.2   2.53   HIG  CONFIRMED VESSEL
# 144 05 Feb 12:02–12:10     8m   10.6×    2.9 119.5    5.5   1.13   HIG  PROBABLE VESSEL
#  70 02 Feb 18:39–18:43     4m   10.5×    0.0   1.1      —      —     —  HIGH ENERGY (no tonals)
# 183 06 Feb 16:41–16:48     7m   10.3×   29.5 331.5    8.3   1.67   HIG  PROBABLE VESSEL
#  74 02 Feb 23:29–23:33     4m   10.2×    1.4  45.3    4.3   0.85   HIG  PROBABLE VESSEL
# 190 07 Feb 01:43–01:48     4m    9.8×   79.7 397.2    5.1   1.01   HIG  PROBABLE VESSEL
# 222 08 Feb 21:25–21:30     4m    9.8×    0.4  23.0      —      —     —  ELEVATED ACTIVITY
# 137 05 Feb 10:48–10:52     4m    9.7×    1.9  82.4   21.6   4.33   LOW  PROBABLE VESSEL
# 104 03 Feb 16:14–16:22     8m    9.7×    3.6  99.7   16.0   3.21   LOW  PROBABLE VESSEL
# 249 10 Feb 17:29–17:36     7m    9.6×    2.9  52.9    9.4   1.88   LOW  PROBABLE VESSEL
# 185 06 Feb 17:31–17:47    16m    9.5×   46.5 393.8   20.8   5.19   HIG  CONFIRMED VESSEL
# 116 04 Feb 09:14–09:44    30m    9.4×   24.7 291.8   22.8   7.59   HIG  CONFIRMED VESSEL
# 248 10 Feb 17:00–17:10    11m    9.0×   65.9 372.7    6.6   1.88   HIG  CONFIRMED VESSEL
# 124 04 Feb 15:54–16:09    14m    8.9×   54.7 328.3   23.5   5.67   HIG  CONFIRMED VESSEL
# 244 10 Feb 13:26–13:30     4m    8.9×    6.9 280.7   17.1   3.42   LOW  PROBABLE VESSEL
# 120 04 Feb 13:43–13:53    10m    8.8×    4.8  41.8    2.4   0.72   HIG  CONFIRMED VESSEL
#  55 01 Feb 06:56–07:03     7m    8.8×    4.6  27.5    2.6   0.66   LOW  PROBABLE VESSEL
# 235 09 Feb 16:13–16:17     4m    8.6×    5.0 152.3    2.7   0.68   HIG  PROBABLE VESSEL
#  38 31 Jan 14:24–14:29     5m    8.6×    5.3  94.7    5.5   1.11   HIG  PROBABLE VESSEL
# 148 05 Feb 12:45–12:55    10m    8.5×   14.1 216.8    5.2   1.20   LOW  CONFIRMED VESSEL
# 226 09 Feb 03:59–04:15    17m    8.3×   81.8 428.8   14.6   3.65   HIG  CONFIRMED VESSEL
# 180 06 Feb 15:28–15:56    28m    8.2×   23.7 299.9    8.7   2.17   HIG  CONFIRMED VESSEL
# 123 04 Feb 15:32–15:45    13m    7.9×   60.8 370.9   24.0   4.80   HIG  CONFIRMED VESSEL
# 181 06 Feb 16:19–16:27     8m    7.8×   37.5 328.7    8.8   2.19   HIG  CONFIRMED VESSEL
# 196 07 Feb 12:49–12:54     5m    7.6×   42.0 329.8    3.2   0.66   HIG  PROBABLE VESSEL
#  54 01 Feb 06:07–06:20    13m    7.5×   64.3 357.3   20.1   5.85   HIG  CONFIRMED VESSEL
#  44 31 Jan 16:20–16:25     5m    7.5×   36.1 324.0    6.2   1.39   HIG  PROBABLE VESSEL
# 225 09 Feb 03:16–03:20     4m    7.5×   13.4 346.3    2.6   0.64   HIG  PROBABLE VESSEL
# 202 07 Feb 16:40–17:00    20m    7.4×   39.6 314.3    3.1   0.77   HIG  CONFIRMED VESSEL
# 182 06 Feb 16:27–16:39    12m    7.1×   36.2 362.8    8.3   2.76   HIG  CONFIRMED VESSEL
# 139 05 Feb 11:12–11:16     4m    7.1×    1.5  49.5    9.0   1.79   HIG  PROBABLE VESSEL
#   9 30 Jan 13:13–13:23    10m    7.0×   57.6 341.3   47.5  11.88   LOW  CONFIRMED VESSEL
# 147 05 Feb 12:35–12:43     8m    6.9×   74.5 328.4    3.3   0.86   HIG  CONFIRMED VESSEL
# 101 03 Feb 15:45–15:49     4m    6.6×    0.2   3.6      —      —     —  ELEVATED ACTIVITY
# 127 04 Feb 17:33–17:37     4m    6.6×    1.7  45.1   10.7   2.14   HIG  PROBABLE VESSEL
# 191 07 Feb 02:59–03:04     5m    6.6×    4.4  29.0      —      —     —  PROBABLE VESSEL
# 194 07 Feb 11:18–11:23     5m    6.5×   36.2 327.2   11.6   2.89   HIG  PROBABLE VESSEL
# 113 04 Feb 07:16–07:21     5m    6.4×    8.6 182.2    2.6   0.68   HIG  PROBABLE VESSEL
#  30 31 Jan 09:58–10:02     4m    6.4×   40.4 254.3   17.1   3.43   HIG  PROBABLE VESSEL
#  33 31 Jan 12:06–12:11     4m    6.3×   13.9 201.2    3.5   1.17   HIG  PROBABLE VESSEL
#  82 03 Feb 09:56–10:05     9m    6.3×   11.1 126.6   20.5   4.15   HIG  CONFIRMED VESSEL
# 151 05 Feb 13:49–14:06    16m    6.1×    2.6  62.8    2.9   0.72   HIG  CONFIRMED VESSEL
# 213 08 Feb 12:35–12:39     4m    6.0×    2.1  30.9      —      —     —  PROBABLE VESSEL
#  78 03 Feb 06:24–06:50    26m    6.0×   30.9 224.9    5.4   1.34   HIG  CONFIRMED VESSEL
#  17 30 Jan 20:07–20:13     6m    5.9×   32.0 286.6    6.5   1.29   HIG  PROBABLE VESSEL
#  15 30 Jan 18:04–18:09     5m    5.9×   41.5 307.4   42.9  10.71   LOW  PROBABLE VESSEL
# 111 04 Feb 03:38–03:42     4m    5.8×    7.6  67.3    3.2   0.65   HIG  PROBABLE VESSEL
#  49 31 Jan 21:28–21:44    16m    5.7×   53.3 302.8    5.7   1.43   HIG  CONFIRMED VESSEL
#  90 03 Feb 12:49–12:59     9m    5.7×   72.1 362.8   19.6   4.36   HIG  CONFIRMED VESSEL
#  12 30 Jan 15:04–15:09     5m    5.7×    5.8  39.7    3.2   0.84   HIG  PROBABLE VESSEL
#  92 03 Feb 13:15–13:19     4m    5.7×    5.6  33.7    5.8   1.16   HIG  PROBABLE VESSEL
# 246 10 Feb 16:15–16:20     4m    5.5×    1.7  59.3    2.2   0.64   HIG  PROBABLE VESSEL
# 216 08 Feb 14:20–14:24     4m    5.5×    1.7  12.9      —      —     —  ELEVATED ACTIVITY
#  60 01 Feb 22:09–22:13     4m    5.5×    0.9  29.1    3.5   0.69   HIG  PROBABLE VESSEL
#   3 30 Jan 10:11–10:22    11m    5.5×   21.9 209.7    6.9   1.37   HIG  CONFIRMED VESSEL
#  31 31 Jan 11:07–11:15     8m    5.5×   76.9 301.2   23.3   5.82   HIG  CONFIRMED VESSEL
#  83 03 Feb 10:06–10:11     4m    5.5×    2.0  13.0   24.9   4.98   LOW  PROBABLE VESSEL
# 168 06 Feb 05:05–05:13     8m    5.3×   10.6 105.9    3.1   0.79   HIG  CONFIRMED VESSEL
#  75 03 Feb 00:19–00:31    12m    5.3×   73.1 320.2   31.7  10.57   LOW  CONFIRMED VESSEL
#  53 01 Feb 05:28–05:32     4m    5.2×    0.5  10.1    5.2   1.03   HIG  ELEVATED ACTIVITY
# 109 04 Feb 01:22–01:29     7m    5.2×   41.9 311.9    3.5   0.87   HIG  PROBABLE VESSEL
# 153 05 Feb 14:34–14:38     4m    5.2×    2.7  73.3    9.8   2.09   HIG  PROBABLE VESSEL
#  29 31 Jan 09:43–09:56    14m    5.2×   23.1 134.1    2.4   0.59   HIG  CONFIRMED VESSEL
# 164 06 Feb 03:26–03:42    15m    5.2×    8.8 121.0    6.6   1.65   HIG  CONFIRMED VESSEL
# 172 06 Feb 07:53–07:57     5m    5.1×   43.8 216.0    6.7   1.69   HIG  PROBABLE VESSEL
#  73 02 Feb 22:47–22:57    10m    5.1×   61.7 279.0   20.0   5.00   HIG  CONFIRMED VESSEL
# 224 09 Feb 00:02–00:07     4m    5.1×    3.0  51.0      —      —     —  PROBABLE VESSEL
# 100 03 Feb 15:20–15:24     4m    5.1×    7.3  49.1    6.8   1.50   HIG  PROBABLE VESSEL
# 178 06 Feb 13:06–13:16    10m    5.1×   52.3 299.1   17.2   3.44   HIG  CONFIRMED VESSEL
# 117 04 Feb 12:48–12:57     9m    5.0×   64.3 252.5    8.6   2.09   HIG  CONFIRMED VESSEL
# 231 09 Feb 08:24–08:34    10m    5.0×   59.4 222.3   23.5   5.29   LOW  CONFIRMED VESSEL
# 135 05 Feb 08:38–08:46     8m    5.0×   19.0 100.6    5.6   1.40   LOW  CONFIRMED VESSEL
#  89 03 Feb 12:35–12:43     8m    4.9×    9.4  36.9   10.9   2.18   LOW  PROBABLE VESSEL
#  86 03 Feb 11:35–11:42     6m    4.9×   10.7 101.4    7.2   2.39   LOW  PROBABLE VESSEL
# 103 03 Feb 16:00–16:09     9m    4.9×    5.8  40.7    8.2   1.64   LOW  CONFIRMED VESSEL
# 187 06 Feb 18:33–18:39     6m    4.9×   49.5 308.7   11.2   3.07   LOW  PROBABLE VESSEL
# 188 07 Feb 00:06–00:24    18m    4.7×   87.1 298.8    4.2   0.85   LOW  CONFIRMED VESSEL
#  23 31 Jan 08:01–08:06     5m    4.6×   44.1 237.1    3.1   0.63   LOW  PROBABLE VESSEL
#  20 31 Jan 03:18–03:25     7m    4.6×   52.9 221.9   34.1   8.53   LOW  PROBABLE VESSEL
# 171 06 Feb 07:39–07:51    11m    4.4×   59.4 258.1   21.7   4.35   LOW  CONFIRMED VESSEL
#  21 31 Jan 05:36–05:51    14m    4.4×   61.4 241.7    7.6   2.37   LOW  CONFIRMED VESSEL
# 208 07 Feb 20:29–20:51    23m    4.3×   14.8  81.8    6.9   1.93   LOW  CONFIRMED VESSEL
# 162 06 Feb 00:48–00:56     8m    4.3×    0.4  28.6    2.9   0.97   LOW  ELEVATED ACTIVITY
# 106 03 Feb 18:44–18:54    10m    4.3×   13.3 108.4    3.6   0.72   LOW  CONFIRMED VESSEL
#   2 30 Jan 09:46–09:53     7m    4.0×    6.4 139.9    3.3   0.67   LOW  PROBABLE VESSEL
# 239 09 Feb 20:47–21:01    14m    3.9×   85.5 313.0    6.2   1.55   LOW  CONFIRMED VESSEL
# 133 05 Feb 07:04–07:14    10m    3.9×    5.8 125.5    2.2   0.73   LOW  CONFIRMED VESSEL
# 193 07 Feb 07:50–07:58     8m    3.8×   64.7 234.6   22.8   5.71   LOW  PROBABLE VESSEL
# 128 04 Feb 17:57–18:08    11m    3.8×   60.0 232.5    6.6   1.64   LOW  CONFIRMED VESSEL
# 211 08 Feb 04:21–04:31    10m    3.7×   75.9 263.7   10.3   2.58   LOW  CONFIRMED VESSEL
# 238 09 Feb 18:34–18:46    12m    3.6×   81.5 295.0    7.6   1.89   LOW  CONFIRMED VESSEL
# 200 07 Feb 16:07–16:19    12m    3.6×   14.4 126.7    9.8   1.96   LOW  CONFIRMED VESSEL
#  77 03 Feb 05:52–05:57     5m    3.5×   28.5  90.5   20.7   6.04   LOW  PROBABLE VESSEL
# 247 10 Feb 16:48–16:56     7m    3.5×    9.8  51.5    3.9   0.79   LOW  PROBABLE VESSEL
# 229 09 Feb 05:51–05:56     6m    3.5×   29.9 133.3   11.6   2.31   LOW  PROBABLE VESSEL
# 129 04 Feb 23:11–23:24    14m    3.4×   30.0 120.0    9.0   3.01   LOW  CONFIRMED VESSEL
# 105 03 Feb 16:59–17:04     5m    3.2×   17.5 129.8    3.4   0.91   LOW  PROBABLE VESSEL
# 184 06 Feb 17:10–17:18     8m    3.1×    9.8  71.4    6.6   1.84   LOW  PROBABLE VESSEL
#  85 03 Feb 11:26–11:31     5m    3.1×    7.6  27.5    7.9   1.98   LOW  PROBABLE VESSEL
#
# Events saved to: /content/drive/MyDrive/SKANN_SSL/lofar_results_all_sessions/transit_events.csv

# %% [markdown]
# ## 8. Generate Event Spectrograms
#
# Zoomed LOFAR spectrograms for the largest events — 3-panel figures showing
# the normalised spectrogram, RMS energy profile, and detected tonals.

# %%
if not GENERATE_EVENT_SPECTROGRAMS:
    print('Event spectrogram generation disabled')
else:
    import matplotlib.dates as mdates
    from matplotlib.dates import DateFormatter as _DF, AutoDateLocator as _ADL
    import matplotlib.gridspec as _gs
    from mpl_toolkits.axes_grid1 import make_axes_locatable

    large_events = [e for e in events if e['rms_ratio'] >= EVENT_SPEC_MIN_RMS_FACTOR]
    large_events = sorted(large_events, key=lambda e: e['rms_ratio'], reverse=True)
    print(f'Generating spectrograms for {len(large_events)} large events (≥{EVENT_SPEC_MIN_RMS_FACTOR}× background)')

    event_spec_start = _time.time()

    for eidx, ev in enumerate(large_events):
        print(f'  [{eidx+1}/{len(large_events)}] Event {ev["event_id"]}: '
              f'{ev["start"].strftime("%d %b %H:%M")}–{ev["end"].strftime("%H:%M")} '
              f'({ev["rms_ratio"]:.0f}×)')

        padded_start = ev['start'] - timedelta(minutes=EVENT_PADDING_MIN)
        padded_end = ev['end'] + timedelta(minutes=EVENT_PADDING_MIN)

        candidate_files = []
        for finfo in all_files:
            if abs((finfo['start_ts'] - ev['start']).total_seconds()) < 7200:
                candidate_files.append(finfo)
        candidate_files = sorted(candidate_files, key=lambda f: f['start_ts'])

        if not candidate_files:
            print('    SKIP: no WAV files found')
            continue

        all_audio = []
        earliest_ts = None
        target_sr = None

        for finfo in candidate_files:
            try:
                data, sr = sf.read(finfo['path'])
            except Exception as e:
                print(f'    WARN: could not read {finfo["path"]}: {e}')
                continue
            if data.ndim > 1:
                data = data[:, 0]
            file_end = finfo['start_ts'] + timedelta(seconds=len(data) / sr)

            if file_end < padded_start or finfo['start_ts'] > padded_end:
                continue

            if earliest_ts is None:
                earliest_ts = finfo['start_ts']
                target_sr = sr

            all_audio.append({
                'data': data, 'sr': sr, 'start': finfo['start_ts']
            })

        if not all_audio or earliest_ts is None:
            print('    SKIP: no overlapping audio')
            continue

        combined = np.concatenate([a['data'] for a in sorted(all_audio, key=lambda a: a['start'])])
        sr = target_sr

        start_offset = max(0, int((padded_start - earliest_ts).total_seconds() * sr))
        end_offset = min(len(combined), int((padded_end - earliest_ts).total_seconds() * sr))
        audio = combined[start_offset:end_offset]
        audio_start_ts = earliest_ts + timedelta(seconds=start_offset / sr)

        if len(audio) < sr * 10:
            print('    SKIP: audio too short')
            continue

        freqs, stft_times, Sxx = compute_stft(audio, sr)
        spec_db, _ = normalise_spectrogram(freqs, stft_times, Sxx)

        stft_mpl = mdates.date2num(np.array(
            [audio_start_ts + timedelta(seconds=float(t)) for t in stft_times],
            dtype='datetime64[ms]'
        ).astype('datetime64[us]'))

        persistent = detect_persistent_tonals(spec_db, freqs, stft_times)
        n_persistent = len(persistent)
        for t in persistent:
            t['start_dt'] = mdates.date2num(audio_start_ts + timedelta(seconds=t['start_sec']))
            t['end_dt'] = mdates.date2num(audio_start_ts + timedelta(seconds=t['end_sec']))

        rms_win = int(sr * 1.0)
        rms_mpl = []
        rms_v = []
        for t_samp in range(0, len(audio) - rms_win, rms_win):
            rms_v.append(float(np.sqrt(np.mean(audio[t_samp:t_samp + rms_win] ** 2))))
            rms_mpl.append(mdates.date2num(audio_start_ts + timedelta(seconds=t_samp / sr)))

        ev_start_mpl = mdates.date2num(ev['start'])
        ev_end_mpl = mdates.date2num(ev['end'])

        total_dur_sec = (padded_end - padded_start).total_seconds()
        tick_interval_min = max(1, round(total_dur_sec / 60 / 5))

        fig = plt.figure(figsize=(20, 13), facecolor=STYLE['bg'])
        gs = _gs.GridSpec(3, 1, height_ratios=[5, 1.6, 1.2], hspace=0.05, figure=fig,
                          left=0.06, right=0.94, top=0.93, bottom=0.06)

        ax1 = fig.add_subplot(gs[0])
        ax2 = fig.add_subplot(gs[1], sharex=ax1)
        ax3 = fig.add_subplot(gs[2], sharex=ax1)

        ax1.set_facecolor(STYLE['bg'])
        freq_mask = freqs <= FREQ_MAX_HZ
        f_sub = freqs[freq_mask]
        im = ax1.pcolormesh(
            stft_mpl, f_sub, spec_db[freq_mask, :],
            cmap=STYLE['cmap'], vmin=-3, vmax=20, shading='auto', rasterized=True
        )
        ax1.axvline(ev_start_mpl, color='#00ff88', lw=1.5, ls='--', alpha=0.8)
        ax1.axvline(ev_end_mpl, color='#00ff88', lw=1.5, ls='--', alpha=0.8)

        for t in persistent[:30]:
            ax1.plot([t['start_dt'], t['end_dt']], [t['freq_hz'], t['freq_hz']],
                     color='#00ff88', lw=1.0, alpha=0.4)

        cbax = ax1.inset_axes([1.01, 0.0, 0.015, 1.0])
        cbar = fig.colorbar(im, cax=cbax)
        cbar.set_label('dB above background', color=STYLE['text'], fontsize=10)
        cbar.ax.tick_params(colors=STYLE['text'])

        ax1.set_ylabel('Frequency (Hz)', color=STYLE['text'], fontsize=11)
        ax1.tick_params(colors=STYLE['text'])
        plt.setp(ax1.get_xticklabels(), visible=False)
        for s in ax1.spines.values():
            s.set_color(STYLE['box_edge'])

        # Title includes DEMON info if available
        demon_str = ''
        if ev.get('blade_rate_hz') and ev.get('demon_confidence') != 'NONE':
            demon_str = f' — BR {ev["blade_rate_hz"]:.1f} Hz, {ev["est_n_blades"]}-blade {ev["est_rpm"]:.0f} RPM ({ev["demon_confidence"]})'
        title = (f'LOFAR — Event {ev["event_id"]} — '
                 f'{ev["start"].strftime("%d %b %H:%M")}–{ev["end"].strftime("%H:%M")} IST — '
                 f'{ev["rms_ratio"]:.0f}× peak — '
                 f'{n_persistent} tonals — {ev["assessment"]}{demon_str}')
        ax1.set_title(title, color=STYLE['text'], fontsize=12, fontweight='bold', pad=12)

        ax2.set_facecolor(STYLE['bg'])
        ax2.fill_between(rms_mpl, rms_v, color=STYLE['accent'], alpha=0.5)
        ax2.plot(rms_mpl, rms_v, color=STYLE['accent'], lw=0.8)
        ax2.axvline(ev_start_mpl, color='#00ff88', lw=1.5, ls='--', alpha=0.8)
        ax2.axvline(ev_end_mpl, color='#00ff88', lw=1.5, ls='--', alpha=0.8)
        ax2.set_ylabel('RMS Energy', color=STYLE['text'], fontsize=10)
        ax2.tick_params(colors=STYLE['text'])
        plt.setp(ax2.get_xticklabels(), visible=False)
        ax2.grid(True, alpha=0.15, color=STYLE['box_edge'])
        for s in ax2.spines.values():
            s.set_color(STYLE['box_edge'])

        ax3.set_facecolor(STYLE['bg'])
        for t in persistent:
            ax3.plot([t['start_dt'], t['end_dt']], [t['freq_hz'], t['freq_hz']],
                     color=STYLE['highlight'], lw=2, alpha=0.7, solid_capstyle='round')
        ax3.axvline(ev_start_mpl, color='#00ff88', lw=1.5, ls='--', alpha=0.8)
        ax3.axvline(ev_end_mpl, color='#00ff88', lw=1.5, ls='--', alpha=0.8)
        ax3.set_ylabel('Tonal (Hz)', color=STYLE['text'], fontsize=10)
        ax3.set_ylim(0, FREQ_MAX_HZ)
        ax3.tick_params(colors=STYLE['text'])
        ax3.grid(True, alpha=0.15, color=STYLE['box_edge'])
        for s in ax3.spines.values():
            s.set_color(STYLE['box_edge'])

        from matplotlib.dates import MinuteLocator as _ML
        ax3.xaxis.set_major_formatter(_DF('%H:%M'))
        ax3.xaxis.set_major_locator(_ML(tick_interval_min))
        ax3.set_xlabel('Time (IST)', color=STYLE['text'], fontsize=11)

        safe_name = ev['start'].strftime('%Y%m%d_%H%M')
        outpath = os.path.join(OUTPUT_DIR,
            f'lofar_event_{ev["event_id"]:02d}_{safe_name}_{ev["rms_ratio"]:.0f}x.png')
        plt.savefig(outpath, dpi=150, facecolor=STYLE['bg'], bbox_inches='tight')
        plt.close()
        print(f'    Saved: {os.path.basename(outpath)}')

        del audio, combined, Sxx, spec_db
        gc.collect()

    print(f'\nEvent spectrograms complete: {(_time.time() - event_spec_start)/60:.1f} min')
# Out:
# Generating spectrograms for 54 large events (≥10.0× background)
#   [1/54] Event 76: 03 Feb 05:25–05:47 (95×)
#     Saved: lofar_event_76_20260203_0525_95x.png
#   [2/54] Event 107: 03 Feb 20:38–20:42 (88×)
#     Saved: lofar_event_107_20260203_2038_88x.png
#   [3/54] Event 64: 02 Feb 08:03–08:07 (76×)
#     Saved: lofar_event_64_20260202_0803_76x.png
#   [4/54] Event 177: 06 Feb 12:55–13:00 (76×)
#     Saved: lofar_event_177_20260206_1255_76x.png
#   [5/54] Event 228: 09 Feb 05:11–05:33 (58×)
#     Saved: lofar_event_228_20260209_0511_58x.png
#   [6/54] Event 142: 05 Feb 11:45–11:51 (57×)
#     Saved: lofar_event_142_20260205_1145_57x.png
#   [7/54] Event 154: 05 Feb 15:17–16:28 (51×)
#     Saved: lofar_event_154_20260205_1517_51x.png
#   [8/54] Event 232: 09 Feb 10:48–10:52 (46×)
#     Saved: lofar_event_232_20260209_1048_46x.png
#   [9/54] Event 158: 05 Feb 17:05–17:34 (45×)
#     Saved: lofar_event_158_20260205_1705_45x.png
#   [10/54] Event 134: 05 Feb 08:10–08:36 (45×)
#     Saved: lofar_event_134_20260205_0810_45x.png
#   [11/54] Event 94: 03 Feb 13:46–14:05 (44×)
#     Saved: lofar_event_94_20260203_1346_44x.png
#   [12/54] Event 243: 10 Feb 11:49–11:54 (42×)
#     Saved: lofar_event_243_20260210_1149_42x.png
#   [13/54] Event 155: 05 Feb 16:31–16:44 (39×)
#     Saved: lofar_event_155_20260205_1631_39x.png
#   [14/54] Event 95: 03 Feb 14:09–14:13 (35×)
#     Saved: lofar_event_95_20260203_1409_35x.png
#   [15/54] Event 160: 05 Feb 19:59–20:09 (34×)
#     Saved: lofar_event_160_20260205_1959_34x.png
#   [16/54] Event 143: 05 Feb 11:54–11:58 (34×)
#     Saved: lofar_event_143_20260205_1154_34x.png
#   [17/54] Event 96: 03 Feb 14:15–14:19 (27×)
#     Saved: lofar_event_96_20260203_1415_27x.png
#   [18/54] Event 132: 05 Feb 04:33–04:39 (27×)
#     Saved: lofar_event_132_20260205_0433_27x.png
#   [19/54] Event 59: 01 Feb 16:04–16:09 (26×)
#     Saved: lofar_event_59_20260201_1604_26x.png
#   [20/54] Event 36: 31 Jan 14:09–14:13 (24×)
#     Saved: lofar_event_36_20260131_1409_24x.png
#   [21/54] Event 93: 03 Feb 13:36–13:44 (24×)
#     Saved: lofar_event_93_20260203_1336_24x.png
#   [22/54] Event 56: 01 Feb 07:59–08:07 (24×)
#     Saved: lofar_event_56_20260201_0759_24x.png
#   [23/54] Event 121: 04 Feb 14:12–14:16 (24×)
#     Saved: lofar_event_121_20260204_1412_24x.png
#   [24/54] Event 131: 05 Feb 00:18–00:22 (22×)
#     Saved: lofar_event_131_20260205_0018_22x.png
#   [25/54] Event 206: 07 Feb 18:00–19:26 (22×)
#     Saved: lofar_event_206_20260207_1800_22x.png
#   [26/54] Event 115: 04 Feb 08:52–09:07 (20×)
#     Saved: lofar_event_115_20260204_0852_20x.png
#   [27/54] Event 43: 31 Jan 15:46–16:10 (19×)
#     Saved: lofar_event_43_20260131_1546_19x.png
#   [28/54] Event 145: 05 Feb 12:11–12:15 (19×)
#     Saved: lofar_event_145_20260205_1211_19x.png
#   [29/54] Event 149: 05 Feb 12:55–13:07 (18×)
#     Saved: lofar_event_149_20260205_1255_18x.png
#   [30/54] Event 141: 05 Feb 11:31–11:38 (18×)
#     Saved: lofar_event_141_20260205_1131_18x.png
#   [31/54] Event 138: 05 Feb 10:59–11:07 (17×)
#     Saved: lofar_event_138_20260205_1059_17x.png
#   [32/54] Event 130: 04 Feb 23:46–23:50 (16×)
#     Saved: lofar_event_130_20260204_2346_16x.png
#   [33/54] Event 19: 31 Jan 00:57–01:02 (15×)
#     Saved: lofar_event_19_20260131_0057_15x.png
#   [34/54] Event 98: 03 Feb 14:42–14:51 (15×)
#     Saved: lofar_event_98_20260203_1442_15x.png
#   [35/54] Event 47: 31 Jan 18:41–18:45 (14×)
#     Saved: lofar_event_47_20260131_1841_14x.png
#   [36/54] Event 25: 31 Jan 08:39–08:53 (14×)
#     Saved: lofar_event_25_20260131_0839_14x.png
#   [37/54] Event 97: 03 Feb 14:20–14:27 (13×)
#     Saved: lofar_event_97_20260203_1420_13x.png
#   [38/54] Event 14: 30 Jan 17:09–17:13 (13×)
#     Saved: lofar_event_14_20260130_1709_13x.png
#   [39/54] Event 186: 06 Feb 18:17–18:30 (13×)
#     Saved: lofar_event_186_20260206_1817_13x.png
#   [40/54] Event 99: 03 Feb 15:08–15:16 (13×)
#     Saved: lofar_event_99_20260203_1508_13x.png
#   [41/54] Event 61: 02 Feb 04:15–04:22 (13×)
#     Saved: lofar_event_61_20260202_0415_13x.png
#   [42/54] Event 45: 31 Jan 16:28–16:32 (13×)
#     Saved: lofar_event_45_20260131_1628_13x.png
#   [43/54] Event 84: 03 Feb 10:25–11:22 (13×)
#     Saved: lofar_event_84_20260203_1025_13x.png
#   [44/54] Event 163: 06 Feb 03:00–03:24 (13×)
#     Saved: lofar_event_163_20260206_0300_13x.png
#   [45/54] Event 241: 10 Feb 07:32–07:36 (13×)
#     Saved: lofar_event_241_20260210_0732_13x.png
#   [46/54] Event 217: 08 Feb 14:51–14:55 (12×)
#     Saved: lofar_event_217_20260208_1451_12x.png
#   [47/54] Event 223: 08 Feb 21:33–21:37 (12×)
#     Saved: lofar_event_223_20260208_2133_12x.png
#   [48/54] Event 233: 09 Feb 11:05–11:09 (12×)
#     Saved: lofar_event_233_20260209_1105_12x.png
#   [49/54] Event 114: 04 Feb 08:31–08:46 (12×)
#     Saved: lofar_event_114_20260204_0831_12x.png
#   [50/54] Event 179: 06 Feb 14:42–15:03 (11×)
#     Saved: lofar_event_179_20260206_1442_11x.png
#   [51/54] Event 144: 05 Feb 12:02–12:10 (11×)
#     Saved: lofar_event_144_20260205_1202_11x.png
#   [52/54] Event 70: 02 Feb 18:39–18:43 (10×)
#     Saved: lofar_event_70_20260202_1839_10x.png
#   [53/54] Event 183: 06 Feb 16:41–16:48 (10×)
#     Saved: lofar_event_183_20260206_1641_10x.png
#   [54/54] Event 74: 02 Feb 23:29–23:33 (10×)
#     Saved: lofar_event_74_20260202_2329_10x.png
#
# Event spectrograms complete: 3.3 min

# %% [markdown]
# ## 9. 48-Hour Timeline Visualisation

# %%
fig, axes = plt.subplots(5, 1, figsize=(22, 20), sharex=True, facecolor=STYLE['bg'])
for ax in axes:
    ax.set_facecolor(STYLE['bg'])
    ax.tick_params(colors=STYLE['text'], labelsize=9)
    for s in ax.spines.values():
        s.set_color(STYLE['box_edge'])
    ax.grid(True, alpha=0.2, color=STYLE['box_edge'])

from matplotlib.dates import DateFormatter

# Panel 1: RMS Energy
ax = axes[0]
colors = [STYLE['red'] if r > rms_thresh else '#2c3e50' for r in df['rms_energy']]
ax.scatter(df['ts'], df['rms_energy'], c=colors, s=3, alpha=0.5)
ax.axhline(rms_thresh, color=STYLE['accent'], ls='--', lw=1,
           label=f'{RMS_SIGMA_THRESHOLD}σ threshold')
ax.set_ylabel('RMS Energy', color=STYLE['text'], fontsize=11)
ax.set_yscale('log')
ax.legend(loc='upper right', fontsize=9, facecolor=STYLE['bg'],
          edgecolor=STYLE['box_edge'], labelcolor=STYLE['text'])
date_start = df['ts'].iloc[0].strftime('%d %b')
date_end = df['ts'].iloc[-1].strftime('%d %b %Y')
ax.set_title(f'LOFAR + DEMON Hydrophone Analysis — NUWR Goa — {date_start} – {date_end}',
             color=STYLE['text'], fontsize=14, fontweight='bold', pad=12)

# Panel 2: Vessel Score
ax = axes[1]
ax.scatter(df['ts'], df['vessel_score'], c=STYLE['accent'], s=3, alpha=0.4)
ax.axhline(2.0, color=STYLE['highlight'], ls='--', lw=1, label='Score = 2')
ax.set_ylabel('Vessel Score', color=STYLE['text'], fontsize=11)
ax.legend(loc='upper right', fontsize=9, facecolor=STYLE['bg'],
          edgecolor=STYLE['box_edge'], labelcolor=STYLE['text'])

# Panel 3: Number of Tonals
ax = axes[2]
ax.scatter(df['ts'], df['n_tonals'], c=STYLE['green'], s=3, alpha=0.4)
ax.set_ylabel('Tonals Detected', color=STYLE['text'], fontsize=11)

# Panel 4: Strongest Tonal Frequency
ax = axes[3]
has_tonal = df['strongest_tonal_hz'] > 0
ax.scatter(df['ts'][has_tonal], df['strongest_tonal_hz'][has_tonal],
           c=STYLE['highlight'], s=5, alpha=0.4)
ax.set_ylabel('Strongest Tonal (Hz)', color=STYLE['text'], fontsize=11)
ax.set_ylim(0, 260)

# Panel 5: DEMON Blade Rate (only where attempted)
ax = axes[4]
demon_mask = df['demon_confidence'] != 'NONE'
high_mask = df['demon_confidence'] == 'HIGH'
low_mask = df['demon_confidence'] == 'LOW'
if low_mask.any():
    ax.scatter(df['ts'][low_mask], df['blade_rate_hz'][low_mask],
               c=STYLE['accent'], s=8, alpha=0.4, label='LOW confidence')
if high_mask.any():
    ax.scatter(df['ts'][high_mask], df['blade_rate_hz'][high_mask],
               c=STYLE['green'], s=15, alpha=0.8, label='HIGH confidence', zorder=5)
ax.set_ylabel('Blade Rate (Hz)', color=STYLE['text'], fontsize=11)
ax.set_ylim(0, 30)
ax.legend(loc='upper right', fontsize=9, facecolor=STYLE['bg'],
          edgecolor=STYLE['box_edge'], labelcolor=STYLE['text'])
ax.xaxis.set_major_formatter(DateFormatter('%d %b\n%H:%M'))
ax.set_xlabel('Time (IST)', color=STYLE['text'], fontsize=11)

plt.tight_layout()
timeline_path = os.path.join(OUTPUT_DIR, 'timeline_48hr_lofar_demon.png')
plt.savefig(timeline_path, dpi=150, facecolor=STYLE['bg'], bbox_inches='tight')
plt.close()
print(f'Timeline saved to: {timeline_path}')
# Out:
# Timeline saved to: /content/drive/MyDrive/SKANN_SSL/lofar_results_all_sessions/timeline_48hr_lofar_demon.png

# %% [markdown]
# ## 10. Customer-Format Output (XLSX)
#
# Generates the spreadsheet in Altair's presentation format:
# - Multi-row per event (one row per primary frequency)
# - Harmonics checked against detected tonal set (shows "2xf, 3xf" or "Not Present")
# - Bearing columns left blank (single hydrophone)
# - DEMON blade rate / shaft rate with confidence in Remarks

# %%
# Generate customer-format XLSX from events
# Multi-row per event matching Altair presentation format

# !pip install openpyxl -q

from openpyxl import Workbook
from openpyxl.styles import Font, PatternFill, Alignment, Border, Side

wb = Workbook()
ws = wb.active
ws.title = 'HAVS Results'

# Styles
header_font_white = Font(bold=True, size=10, name='Arial', color='FFFFFF')
header_fill = PatternFill('solid', fgColor='4472C4')
sub_header_fill = PatternFill('solid', fgColor='D6E4F0')
sub_header_font = Font(bold=True, size=9, name='Arial')
data_font = Font(size=9, name='Arial')
thin_border = Border(
    left=Side(style='thin'), right=Side(style='thin'),
    top=Side(style='thin'), bottom=Side(style='thin')
)
center = Alignment(horizontal='center', vertical='center', wrap_text=True)
left_align = Alignment(horizontal='left', vertical='center', wrap_text=True)

# Row 1: Main headers (merged)
main_headers = {
    'A1': 'Date', 'B1': 'Time',
    'C1': 'Spectrogram Features',
    'E1': 'Bearing Features',
    'H1': 'LOFAR Features',
    'J1': 'DEMON Features',
    'L1': 'Event', 'M1': 'Remarks'
}
for cell_ref, text in main_headers.items():
    ws[cell_ref] = text
    ws[cell_ref].font = header_font_white
    ws[cell_ref].fill = header_fill
    ws[cell_ref].alignment = center
    ws[cell_ref].border = thin_border

ws.merge_cells('C1:D1')
ws.merge_cells('E1:G1')
ws.merge_cells('H1:I1')
ws.merge_cells('J1:K1')

for col in range(1, 14):
    cell = ws.cell(row=1, column=col)
    cell.border = thin_border
    if not cell.value:
        cell.fill = header_fill

# Row 2: Sub-headers
sub_headers = [
    '', '',
    'Primary Frequencies (Hz)', 'Harmonics (Hz)',
    'Bearing Angle (\u00b0)', 'BTR Curve Feature', 'Estimated Speed (kn)',
    'Primary Frequencies (Hz)', 'Harmonics (Hz)',
    'Blade Rate (Hz)', 'Shaft Rate (Hz)',
    '', ''
]
for col, text in enumerate(sub_headers, 1):
    cell = ws.cell(row=2, column=col, value=text)
    cell.font = sub_header_font
    cell.fill = sub_header_fill
    cell.alignment = center
    cell.border = thin_border

# Column widths
for col_letter, w in {'A': 12, 'B': 14, 'C': 18, 'D': 20, 'E': 12, 'F': 14,
                       'G': 14, 'H': 18, 'I': 20, 'J': 12, 'K': 12, 'L': 18, 'M': 40}.items():
    ws.column_dimensions[col_letter].width = w

# Process events into multi-row format
row = 3
current_date = None

for ev in sorted(events, key=lambda e: e['start']):
    if ev['assessment'] == 'brief transient':
        continue

    date_str = ev['start'].strftime('%d/%m/%Y')
    time_str = f'{ev["start"].strftime("%H:%M")}-{ev["end"].strftime("%H:%M")}'

    # Get all windows for this event
    mask = (df['ts'] >= ev['start']) & (df['ts'] <= ev['end'])
    ev_windows = df[mask]

    # Collect all tonal frequencies from this event
    all_tonals = []
    for _, win_row in ev_windows.iterrows():
        tf = str(win_row.get('tonal_freqs', ''))
        if tf and tf != '' and tf != 'nan':
            for f in tf.split('|'):
                try:
                    all_tonals.append(float(f))
                except ValueError:
                    pass

    # Get top primary frequencies by occurrence
    if all_tonals:
        from collections import Counter
        rounded = [round(f, 0) for f in all_tonals]
        freq_counts = Counter(rounded)
        primary_freqs = [f for f, _ in freq_counts.most_common(5)]
    else:
        primary_freqs = []

    all_freq_set = set(int(round(f)) for f in all_tonals)

    # Remarks - clean ASCII
    remarks_parts = [ev['assessment']]
    if ev.get('demon_confidence') and ev['demon_confidence'] != 'NONE':
        remarks_parts.append(f'DEMON: {ev["demon_confidence"]} confidence')
        if ev.get('est_n_blades') and ev.get('est_rpm'):
            remarks_parts.append(f'{ev["est_n_blades"]}-blade {ev["est_rpm"]:.0f} RPM')
    remarks_parts.append(f'{ev["rms_ratio"]:.0f}x background')
    if ev.get('demon_confidence') == 'NONE' and ev['rms_ratio'] >= SIGNIFICANT_RMS_FACTOR:
        remarks_parts.append('DEMON: not attempted (insufficient tonals)')
    remarks = '; '.join(remarks_parts)

    n_rows = max(len(primary_freqs), 1)

    # Date (only on change)
    if date_str != current_date:
        ws.cell(row=row, column=1, value=date_str).font = data_font
        ws.cell(row=row, column=1).alignment = left_align
        current_date = date_str

    # Time, Event, Remarks on first row
    ws.cell(row=row, column=2, value=time_str).font = data_font
    ws.cell(row=row, column=2).alignment = left_align
    ws.cell(row=row, column=12, value=ev['assessment']).font = data_font
    ws.cell(row=row, column=12).alignment = left_align
    ws.cell(row=row, column=13, value=remarks).font = data_font
    ws.cell(row=row, column=13).alignment = left_align

    # DEMON on first row
    if ev.get('blade_rate_hz') and ev['demon_confidence'] != 'NONE':
        ws.cell(row=row, column=10, value=round(ev['blade_rate_hz'], 1)).font = data_font
        ws.cell(row=row, column=10).alignment = center
    if ev.get('shaft_rate_hz') and ev['demon_confidence'] != 'NONE':
        ws.cell(row=row, column=11, value=round(ev['shaft_rate_hz'], 2)).font = data_font
        ws.cell(row=row, column=11).alignment = center

    # Each primary frequency on its own row
    for fi in range(n_rows):
        r = row + fi
        if fi < len(primary_freqs):
            freq_int = int(round(primary_freqs[fi]))

            # Spectrogram column
            ws.cell(row=r, column=3, value=freq_int).font = data_font
            ws.cell(row=r, column=3).alignment = center

            # Harmonics: check 2x and 3x
            h2 = freq_int * 2
            h3 = freq_int * 3
            h2_ok = h2 in all_freq_set
            h3_ok = h3 in all_freq_set
            if h2_ok and h3_ok:
                harm = f'{h2}, {h3}'
            elif h2_ok:
                harm = str(h2)
            elif h3_ok:
                harm = str(h3)
            else:
                harm = 'Not Present'
            ws.cell(row=r, column=4, value=harm).font = data_font
            ws.cell(row=r, column=4).alignment = center

            # LOFAR columns (same data)
            ws.cell(row=r, column=8, value=freq_int).font = data_font
            ws.cell(row=r, column=8).alignment = center
            ws.cell(row=r, column=9, value=harm).font = data_font
            ws.cell(row=r, column=9).alignment = center

        # Borders on all cells
        for col in range(1, 14):
            ws.cell(row=r, column=col).border = thin_border

    row += n_rows

# Notes
row += 2
ws.cell(row=row, column=5, value='BTR = Bearing-Time Record').font = Font(size=8, italic=True, name='Arial')
row += 1
ws.cell(row=row, column=1, value='Notes:').font = Font(size=8, bold=True, name='Arial')
row += 1
ws.cell(row=row, column=1, value='Bearing features require multi-element array; single hydrophone deployment - no bearing data available.').font = Font(size=8, italic=True, name='Arial')
row += 1
ws.cell(row=row, column=1, value='DEMON blade rate / shaft rate: extracted via Hilbert envelope analysis at 512 Hz. Confidence noted in Remarks.').font = Font(size=8, italic=True, name='Arial')
row += 1
ws.cell(row=row, column=1, value='HIGH = harmonics confirmed + strong RMS + multiple tonals; LOW = gate passed but fewer confirming indicators.').font = Font(size=8, italic=True, name='Arial')

ws.freeze_panes = 'A3'

xlsx_path = os.path.join(OUTPUT_DIR, 'havs_goa_results.xlsx')
wb.save(xlsx_path)
print(f'Customer XLSX saved: {xlsx_path}')
print(f'Significant events: {sum(1 for e in events if e["assessment"] != "brief transient")}')
# Out:
# Customer XLSX saved: /content/drive/MyDrive/SKANN_SSL/lofar_results_all_sessions/havs_goa_results.xlsx
# Significant events: 148

# %% [markdown]
# ## 11. Final Summary

# %%
print('='*60)
print('LOFAR + DEMON HYDROPHONE ANALYSIS — COMPLETE')
print('='*60)
print(f'\nData processed: {len(df)} windows from {df["session"].nunique()} files')
print(f'Date range: {df["ts"].min().strftime("%d %b %H:%M")} → {df["ts"].max().strftime("%d %b %H:%M")}')
print(f'\nStage 1 (RMS Detection):')
print(f'  Dynamic range: {df["rms_energy"].max()/df["rms_energy"].min():.0f}×')
print(f'  Elevated windows: {(df["rms_energy"] > rms_thresh).sum()} ({100*(df["rms_energy"] > rms_thresh).sum()/len(df):.1f}%)')
print(f'\nStage 2 (LOFAR Classification):')
print(f'  Windows with tonals: {(df["n_tonals"] > 0).sum()} ({100*(df["n_tonals"] > 0).sum()/len(df):.1f}%)')
print(f'\nStage 3 (DEMON Characterisation):')
demon_attempted = (df['demon_confidence'] != 'NONE').sum()
print(f'  DEMON attempted: {demon_attempted} windows ({100*demon_attempted/len(df):.1f}%)')
print(f'  HIGH confidence: {(df["demon_confidence"] == "HIGH").sum()} windows')
print(f'  LOW confidence:  {(df["demon_confidence"] == "LOW").sum()} windows')
print(f'\nEvent Summary:')
print(f'  Total events: {len(events)}')
print(f'  Significant transits: {len(significant)}')
confirmed = [e for e in significant if 'CONFIRMED' in e.get('assessment', '')]
probable = [e for e in significant if 'PROBABLE' in e.get('assessment', '')]
print(f'  Confirmed vessels: {len(confirmed)}')
print(f'  Probable vessels: {len(probable)}')
print(f'\nOutput files in {OUTPUT_DIR}:')
for f in sorted(os.listdir(OUTPUT_DIR)):
    if not f.startswith('.') and not f.startswith('_'):
        fpath = os.path.join(OUTPUT_DIR, f)
        size = os.path.getsize(fpath)
        print(f'  {f:55s} {size/1024:>8.0f} KB')
# Out:
# ============================================================
# LOFAR + DEMON HYDROPHONE ANALYSIS — COMPLETE
# ============================================================
#
# Data processed: 67887 windows from 288 files
# Date range: 30 Jan 09:04 → 11 Feb 07:01
#
# Stage 1 (RMS Detection):
#   Dynamic range: 439×
#   Elevated windows: 2774 (4.1%)
#
# Stage 2 (LOFAR Classification):
#   Windows with tonals: 38152 (56.2%)
#
# Stage 3 (DEMON Characterisation):
#   DEMON attempted: 2326 windows (3.4%)
#   HIGH confidence: 609 windows
#   LOW confidence:  1717 windows
#
# Event Summary:
#   Total events: 250
#   Significant transits: 148
#   Confirmed vessels: 67
#   Probable vessels: 72
#
# Output files in /content/drive/MyDrive/SKANN_SSL/lofar_results_all_sessions/:
#   havs_goa_results.xlsx                                         40 KB
#   lofar_event_107_20260203_2038_88x.png                       2501 KB
#   lofar_event_114_20260204_0831_12x.png                       4130 KB
#   lofar_event_115_20260204_0852_20x.png                       4224 KB
#   lofar_event_121_20260204_1412_24x.png                       2576 KB
#   lofar_event_130_20260204_2346_16x.png                       2662 KB
#   lofar_event_131_20260205_0018_22x.png                       2579 KB
#   lofar_event_132_20260205_0433_27x.png                       2880 KB
#   lofar_event_134_20260205_0810_45x.png                       4932 KB
#   lofar_event_138_20260205_1059_17x.png                       3418 KB
#   lofar_event_141_20260205_1131_18x.png                       3044 KB
#   lofar_event_142_20260205_1145_57x.png                       3035 KB
#   lofar_event_143_20260205_1154_34x.png                       2612 KB
#   lofar_event_144_20260205_1202_11x.png                       3319 KB
#   lofar_event_145_20260205_1211_19x.png                       2626 KB
#   lofar_event_149_20260205_1255_18x.png                       3761 KB
#   lofar_event_14_20260130_1709_13x.png                        2593 KB
#   lofar_event_154_20260205_1517_51x.png                       6547 KB
#   lofar_event_155_20260205_1631_39x.png                       3928 KB
#   lofar_event_158_20260205_1705_45x.png                       5914 KB
#   lofar_event_160_20260205_1959_34x.png                       3269 KB
#   lofar_event_163_20260206_0300_13x.png                       5252 KB
#   lofar_event_177_20260206_1255_76x.png                       2563 KB
#   lofar_event_179_20260206_1442_11x.png                       5007 KB
#   lofar_event_183_20260206_1641_10x.png                       3072 KB
#   lofar_event_186_20260206_1817_13x.png                       3822 KB
#   lofar_event_19_20260131_0057_15x.png                        2752 KB
#   lofar_event_206_20260207_1800_22x.png                       6701 KB
#   lofar_event_217_20260208_1451_12x.png                       2570 KB
#   lofar_event_223_20260208_2133_12x.png                       2550 KB
#   lofar_event_228_20260209_0511_58x.png                       5130 KB
#   lofar_event_232_20260209_1048_46x.png                       2704 KB
#   lofar_event_233_20260209_1105_12x.png                       2711 KB
#   lofar_event_241_20260210_0732_13x.png                       2600 KB
#   lofar_event_243_20260210_1149_42x.png                       2760 KB
#   lofar_event_25_20260131_0839_14x.png                        3976 KB
#   lofar_event_36_20260131_1409_24x.png                        2563 KB
#   lofar_event_43_20260131_1546_19x.png                        5446 KB
#   lofar_event_45_20260131_1628_13x.png                        2593 KB
#   lofar_event_47_20260131_1841_14x.png                        2557 KB
#   lofar_event_56_20260201_0759_24x.png                        3111 KB
#   lofar_event_59_20260201_1604_26x.png                        2594 KB
#   lofar_event_61_20260202_0415_13x.png                        3208 KB
#   lofar_event_64_20260202_0803_76x.png                        2623 KB
#   lofar_event_70_20260202_1839_10x.png                        2557 KB
#   lofar_event_74_20260202_2329_10x.png                        2582 KB
#   lofar_event_76_20260203_0525_95x.png                        4799 KB
#   lofar_event_84_20260203_1025_13x.png                        6266 KB
#   lofar_event_93_20260203_1336_24x.png                        3299 KB
#   lofar_event_94_20260203_1346_44x.png                        4759 KB
#   lofar_event_95_20260203_1409_35x.png                        2585 KB
#   lofar_event_96_20260203_1415_27x.png                        2589 KB
#   lofar_event_97_20260203_1420_13x.png                        3022 KB
#   lofar_event_98_20260203_1442_15x.png                        3453 KB
#   lofar_event_99_20260203_1508_13x.png                        3308 KB
#   lofar_hydrophone_results.csv                               13088 KB
#   lofar_session_1.png                                         2201 KB
#   lofar_session_10.png                                        2283 KB
#   lofar_session_100.png                                       2246 KB
#   lofar_session_101.png                                       2205 KB
#   lofar_session_102.png                                       2264 KB
#   lofar_session_103.png                                       2225 KB
#   lofar_session_104.png                                       2277 KB
#   lofar_session_105.png                                       2258 KB
#   lofar_session_106.png                                       2238 KB
#   lofar_session_107.png                                       2257 KB
#   lofar_session_108.png                                       2164 KB
#   lofar_session_109.png                                       2268 KB
#   lofar_session_11.png                                        2283 KB
#   lofar_session_110.png                                       2278 KB
#   lofar_session_111.png                                       2307 KB
#   lofar_session_112.png                                       2294 KB
#   lofar_session_113.png                                       2224 KB
#   lofar_session_114.png                                       2293 KB
#   lofar_session_115.png                                       2298 KB
#   lofar_session_116.png                                       2263 KB
#   lofar_session_117.png                                       2278 KB
#   lofar_session_118.png                                       2298 KB
#   lofar_session_119.png                                       2264 KB
#   lofar_session_12.png                                        2192 KB
#   lofar_session_120.png                                       2106 KB
#   lofar_session_121.png                                       2082 KB
#   lofar_session_122.png                                       2280 KB
#   lofar_session_123.png                                       2155 KB
#   lofar_session_124.png                                       2228 KB
#   lofar_session_125.png                                       2123 KB
#   lofar_session_126.png                                       2224 KB
#   lofar_session_127.png                                       2147 KB
#   lofar_session_128.png                                       2223 KB
#   lofar_session_129.png                                       2302 KB
#   lofar_session_13.png                                        2297 KB
#   lofar_session_130.png                                       2184 KB
#   lofar_session_131.png                                       2298 KB
#   lofar_session_132.png                                       2230 KB
#   lofar_session_133.png                                       2267 KB
#   lofar_session_134.png                                       2226 KB
#   lofar_session_135.png                                       2174 KB
#   lofar_session_136.png                                       2215 KB
#   lofar_session_137.png                                       2231 KB
#   lofar_session_138.png                                       2318 KB
#   lofar_session_139.png                                       2264 KB
#   lofar_session_14.png                                        2300 KB
#   lofar_session_140.png                                       2185 KB
#   lofar_session_141.png                                       2260 KB
#   lofar_session_142.png                                       2275 KB
#   lofar_session_143.png                                       2272 KB
#   lofar_session_144.png                                        555 KB
#   lofar_session_145.png                                       1917 KB
#   lofar_session_146.png                                       2310 KB
#   lofar_session_147.png                                       2222 KB
#   lofar_session_148.png                                       2199 KB
#   lofar_session_149.png                                       2146 KB
#   lofar_session_15.png                                        2328 KB
#   lofar_session_150.png                                       2240 KB
#   lofar_session_151.png                                       2226 KB
#   lofar_session_152.png                                       2181 KB
#   lofar_session_153.png                                       2225 KB
#   lofar_session_154.png                                       2214 KB
#   lofar_session_155.png                                       2180 KB
#   lofar_session_156.png                                       2286 KB
#   lofar_session_157.png                                       2137 KB
#   lofar_session_158.png                                       2223 KB
#   lofar_session_159.png                                       2281 KB
#   lofar_session_16.png                                        2255 KB
#   lofar_session_160.png                                       2332 KB
#   lofar_session_161.png                                       2294 KB
#   lofar_session_162.png                                       2346 KB
#   lofar_session_163.png                                       2300 KB
#   lofar_session_164.png                                       2094 KB
#   lofar_session_165.png                                       2283 KB
#   lofar_session_166.png                                       2270 KB
#   lofar_session_167.png                                       2256 KB
#   lofar_session_168.png                                       2169 KB
#   lofar_session_169.png                                       2271 KB
#   lofar_session_17.png                                        2229 KB
#   lofar_session_170.png                                       2295 KB
#   lofar_session_171.png                                       2236 KB
#   lofar_session_172.png                                       2267 KB
#   lofar_session_173.png                                       2238 KB
#   lofar_session_174.png                                       2153 KB
#   lofar_session_175.png                                       2152 KB
#   lofar_session_176.png                                       2130 KB
#   lofar_session_177.png                                       2114 KB
#   lofar_session_178.png                                       2128 KB
#   lofar_session_179.png                                       2084 KB
#   lofar_session_18.png                                        2192 KB
#   lofar_session_180.png                                       2227 KB
#   lofar_session_181.png                                       2298 KB
#   lofar_session_182.png                                       2207 KB
#   lofar_session_183.png                                       2261 KB
#   lofar_session_184.png                                       2309 KB
#   lofar_session_185.png                                       2003 KB
#   lofar_session_186.png                                       2148 KB
#   lofar_session_187.png                                       2302 KB
#   lofar_session_188.png                                       2297 KB
#   lofar_session_189.png                                       2293 KB
#   lofar_session_19.png                                        2207 KB
#   lofar_session_190.png                                       2279 KB
#   lofar_session_191.png                                       2294 KB
#   lofar_session_192.png                                       2220 KB
#   lofar_session_193.png                                       2255 KB
#   lofar_session_194.png                                       2317 KB
#   lofar_session_195.png                                       2280 KB
#   lofar_session_196.png                                       2253 KB
#   lofar_session_197.png                                       2207 KB
#   lofar_session_198.png                                       2271 KB
#   lofar_session_199.png                                       2234 KB
#   lofar_session_2.png                                         2257 KB
#   lofar_session_20.png                                        2258 KB
#   lofar_session_200.png                                       2250 KB
#   lofar_session_201.png                                       2133 KB
#   lofar_session_202.png                                       2188 KB
#   lofar_session_203.png                                       2169 KB
#   lofar_session_204.png                                       2157 KB
#   lofar_session_205.png                                       2155 KB
#   lofar_session_206.png                                       2279 KB
#   lofar_session_207.png                                       2266 KB
#   lofar_session_208.png                                       2301 KB
#   lofar_session_209.png                                       2318 KB
#   lofar_session_21.png                                        2150 KB
#   lofar_session_210.png                                       2327 KB
#   lofar_session_211.png                                       2322 KB
#   lofar_session_212.png                                       2260 KB
#   lofar_session_213.png                                       2120 KB
#   lofar_session_214.png                                       2279 KB
#   lofar_session_215.png                                       2292 KB
#   lofar_session_216.png                                       2290 KB
#   lofar_session_217.png                                       2303 KB
#   lofar_session_218.png                                       2310 KB
#   lofar_session_219.png                                       2304 KB
#   lofar_session_22.png                                        2276 KB
#   lofar_session_220.png                                       2281 KB
#   lofar_session_221.png                                       2271 KB
#   lofar_session_222.png                                       2275 KB
#   lofar_session_223.png                                       2264 KB
#   lofar_session_224.png                                       2201 KB
#   lofar_session_225.png                                       2226 KB
#   lofar_session_226.png                                       2217 KB
#   lofar_session_227.png                                       2209 KB
#   lofar_session_228.png                                       2240 KB
#   lofar_session_229.png                                       2300 KB
#   lofar_session_23.png                                        2258 KB
#   lofar_session_230.png                                       2305 KB
#   lofar_session_231.png                                       2300 KB
#   lofar_session_232.png                                       2297 KB
#   lofar_session_233.png                                       2302 KB
#   lofar_session_234.png                                       2301 KB
#   lofar_session_235.png                                       2311 KB
#   lofar_session_236.png                                       2213 KB
#   lofar_session_237.png                                       2116 KB
#   lofar_session_238.png                                       2166 KB
#   lofar_session_239.png                                       2213 KB
#   lofar_session_24.png                                        2140 KB
#   lofar_session_240.png                                       2160 KB
#   lofar_session_241.png                                       2218 KB
#   lofar_session_242.png                                       2238 KB
#   lofar_session_243.png                                       2260 KB
#   lofar_session_244.png                                       2282 KB
#   lofar_session_245.png                                       2275 KB
#   lofar_session_246.png                                       2271 KB
#   lofar_session_247.png                                       2304 KB
#   lofar_session_248.png                                       2309 KB
#   lofar_session_249.png                                       2314 KB
#   lofar_session_25.png                                        2144 KB
#   lofar_session_250.png                                       2328 KB
#   lofar_session_251.png                                       2179 KB
#   lofar_session_252.png                                       2329 KB
#   lofar_session_253.png                                       2274 KB
#   lofar_session_254.png                                       2187 KB
#   lofar_session_255.png                                       2265 KB
#   lofar_session_256.png                                       2239 KB
#   lofar_session_257.png                                       2327 KB
#   lofar_session_258.png                                       2327 KB
#   lofar_session_259.png                                       2216 KB
#   lofar_session_26.png                                        2194 KB
#   lofar_session_260.png                                       2282 KB
#   lofar_session_261.png                                       2285 KB
#   lofar_session_262.png                                       2276 KB
#   lofar_session_263.png                                       2282 KB
#   lofar_session_264.png                                       2238 KB
#   lofar_session_265.png                                       2270 KB
#   lofar_session_266.png                                       2249 KB
#   lofar_session_267.png                                       2268 KB
#   lofar_session_268.png                                       2194 KB
#   lofar_session_269.png                                       2238 KB
#   lofar_session_27.png                                        2158 KB
#   lofar_session_270.png                                       2202 KB
#   lofar_session_271.png                                       2281 KB
#   lofar_session_272.png                                       2307 KB
#   lofar_session_273.png                                       2186 KB
#   lofar_session_274.png                                       2190 KB
#   lofar_session_275.png                                       2266 KB
#   lofar_session_276.png                                       2247 KB
#   lofar_session_277.png                                       2323 KB
#   lofar_session_278.png                                       2283 KB
#   lofar_session_279.png                                       2304 KB
#   lofar_session_28.png                                        2258 KB
#   lofar_session_280.png                                       2292 KB
#   lofar_session_281.png                                       2310 KB
#   lofar_session_282.png                                       2307 KB
#   lofar_session_283.png                                       2299 KB
#   lofar_session_284.png                                       2271 KB
#   lofar_session_285.png                                       2289 KB
#   lofar_session_286.png                                       2274 KB
#   lofar_session_287.png                                       2277 KB
#   lofar_session_288.png                                       1122 KB
#   lofar_session_29.png                                        2110 KB
#   lofar_session_3.png                                         2175 KB
#   lofar_session_30.png                                        2207 KB
#   lofar_session_31.png                                        2198 KB
#   lofar_session_32.png                                        2236 KB
#   lofar_session_33.png                                        2237 KB
#   lofar_session_34.png                                        2245 KB
#   lofar_session_35.png                                        2286 KB
#   lofar_session_36.png                                        2292 KB
#   lofar_session_37.png                                        2187 KB
#   lofar_session_38.png                                        2275 KB
#   lofar_session_39.png                                        2308 KB
#   lofar_session_4.png                                         2231 KB
#   lofar_session_40.png                                        2317 KB
#   lofar_session_41.png                                        2331 KB
#   lofar_session_42.png                                        2332 KB
#   lofar_session_43.png                                        2335 KB
#   lofar_session_44.png                                        2303 KB
#   lofar_session_45.png                                        2269 KB
#   lofar_session_46.png                                        2131 KB
#   lofar_session_47.png                                        2208 KB
#   lofar_session_48.png                                        1955 KB
#   lofar_session_49.png                                        2226 KB
#   lofar_session_5.png                                         2192 KB
#   lofar_session_50.png                                        2213 KB
#   lofar_session_51.png                                        2264 KB
#   lofar_session_52.png                                        2240 KB
#   lofar_session_53.png                                        2265 KB
#   lofar_session_54.png                                        2248 KB
#   lofar_session_55.png                                        2243 KB
#   lofar_session_56.png                                        2296 KB
#   lofar_session_57.png                                        2277 KB
#   lofar_session_58.png                                        2226 KB
#   lofar_session_59.png                                        2198 KB
#   lofar_session_6.png                                         2235 KB
#   lofar_session_60.png                                        2258 KB
#   lofar_session_61.png                                        2299 KB
#   lofar_session_62.png                                        2251 KB
#   lofar_session_63.png                                        2306 KB
#   lofar_session_64.png                                        2335 KB
#   lofar_session_65.png                                        2319 KB
#   lofar_session_66.png                                        2331 KB
#   lofar_session_67.png                                        2325 KB
#   lofar_session_68.png                                        2254 KB
#   lofar_session_69.png                                        2258 KB
#   lofar_session_7.png                                         2234 KB
#   lofar_session_70.png                                        2261 KB
#   lofar_session_71.png                                        2267 KB
#   lofar_session_72.png                                        2288 KB
#   lofar_session_73.png                                        2176 KB
#   lofar_session_74.png                                        2304 KB
#   lofar_session_75.png                                        2295 KB
#   lofar_session_76.png                                        2288 KB
#   lofar_session_77.png                                        2303 KB
#   lofar_session_78.png                                        2185 KB
#   lofar_session_79.png                                        2244 KB
#   lofar_session_8.png                                         2248 KB
#   lofar_session_80.png                                        2262 KB
#   lofar_session_81.png                                        2210 KB
#   lofar_session_82.png                                        2232 KB
#   lofar_session_83.png                                        2243 KB
#   lofar_session_84.png                                        2171 KB
#   lofar_session_85.png                                        2290 KB
#   lofar_session_86.png                                        2250 KB
#   lofar_session_87.png                                        2257 KB
#   lofar_session_88.png                                        2136 KB
#   lofar_session_89.png                                        2304 KB
#   lofar_session_9.png                                         2283 KB
#   lofar_session_90.png                                        2309 KB
#   lofar_session_91.png                                        2285 KB
#   lofar_session_92.png                                        2261 KB
#   lofar_session_93.png                                        1780 KB
#   lofar_session_94.png                                        2099 KB
#   lofar_session_95.png                                        2266 KB
#   lofar_session_96.png                                        2277 KB
#   lofar_session_97.png                                        2246 KB
#   lofar_session_98.png                                        2095 KB
#   lofar_session_99.png                                        2121 KB
#   timeline_48hr_lofar_demon.png                               1924 KB
#   transit_events.csv                                            33 KB
